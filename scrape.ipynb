# %%
import requests
from bs4 import BeautifulSoup
import json

# Base URL of the thesis list
base_url = "https://research.tue.nl/en/studentTheses/"
params = {
  'organisationIds': '49ca0778-93f6-4b7f-95be-d4cbfb3be718',
  'nofollow': 'true',
  'type': '/dk/atira/pure/studentthesis/studentthesistypes/studentthesis/master',
  'page': 0  # This will be changed in the loop
}

# Function to scrape a single page
def scrape_page(page_num):
  # Set the page parameter
  params['page'] = page_num
  # Send the request to the website
  response = requests.get(base_url, params=params)
  # Parse the page content
  soup = BeautifulSoup(response.text, 'html.parser')
  # Find all thesis entries
  theses = soup.find_all('div', class_='rendering_studentthesis_short')

  # Extract title and link for each thesis
  thesis_data = []
  for thesis in theses:
    title_tag = thesis.find('h3', class_='title').find('a')
    title = title_tag.get_text(strip=True)
    link = title_tag['href']
    # Append the full URL to the link
    full_link = base_url + link if not link.startswith('http') else link
    thesis_data.append({
      "Title": title,
      "URL": full_link
    })
  
  return thesis_data

# Function to scrape all pages and save the results
def scrape_all_pages():
  all_theses = []
  for page_num in range(8):  # 0 to 7 pages
    print(f"Scraping page {page_num}...")
    theses = scrape_page(page_num)
    all_theses.extend(theses)
  
  # Save to a JSON file
  with open('thesis_titles_and_links.json', 'w', encoding='utf-8') as f:
    json.dump(all_theses, f, ensure_ascii=False, indent=4)
  
  print(f"Scraped {len(all_theses)} theses in total.")

# Run the scraper
scrape_all_pages()
# Out:
# Scraping page 0...
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraped 400 theses in total.

# %%
# import requests
# from bs4 import BeautifulSoup
# import json
# import time

# # Base URL of the thesis list and PDF files
# base_url = "https://research.tue.nl"

# # Function to scrape a single page for thesis titles and URLs
# def scrape_page(page_num):
#   thesis_page_url = f"{base_url}/en/studentTheses/"
#   params = {
#     'organisationIds': '49ca0778-93f6-4b7f-95be-d4cbfb3be718',
#     'nofollow': 'true',
#     'type': '/dk/atira/pure/studentthesis/studentthesistypes/studentthesis/master',
#     'page': page_num
#   }

#   response = requests.get(thesis_page_url, params=params)
#   soup = BeautifulSoup(response.text, 'html.parser')
#   theses = soup.find_all('div', class_='rendering_studentthesis_short')

#   thesis_data = []
#   for thesis in theses:
#     title_tag = thesis.find('h3', class_='title').find('a')
#     title = title_tag.get_text(strip=True)
#     link = title_tag['href']
#     full_link = base_url + link if not link.startswith('http') else link
#     thesis_data.append({
#       "Title": title,
#       "URL": full_link
#     })
  
#   return thesis_data

# # Function to scrape the PDF link from a thesis page
# def scrape_pdf_link(thesis_url):
#   response = requests.get(thesis_url)
#   soup = BeautifulSoup(response.text, 'html.parser')

#   # Look for the documents section
#   documents_section = soup.find('div', class_='documents')
#   if documents_section:
#     pdf_link_tag = documents_section.find('a', class_='link')
#     if pdf_link_tag and pdf_link_tag.get('href').endswith('.pdf'):
#       pdf_relative_url = pdf_link_tag['href']
#       pdf_full_url = base_url + pdf_relative_url  # Get the full PDF URL
#       return pdf_full_url
#   return None  # If no PDF link found

# # Function to scrape all pages and get thesis titles, URLs, and PDF links
# def scrape_all_theses():
#   all_theses = []
#   for page_num in range(8):  # 0 to 7 pages
#     print(f"Scraping page {page_num}...")
#     theses = scrape_page(page_num)
    
#     for thesis in theses:
#       print(f"Scraping PDF link for: {thesis['Title']}")
#       pdf_link = scrape_pdf_link(thesis['URL'])
#       thesis["PDF"] = pdf_link  # Add the PDF link to the JSON entry
#       time.sleep(1)  # Be nice to the server and add a delay

#     all_theses.extend(theses)
  
#   # Save all theses data to a JSON file
#   with open('thesis_titles_links_and_pdfs.json', 'w', encoding='utf-8') as f:
#     json.dump(all_theses, f, ensure_ascii=False, indent=4)

#   print(f"Scraped {len(all_theses)} theses in total.")

# # Run the scraper
# scrape_all_theses()
# Out:
# Scraping page 0...
# Scraping PDF link for: /JoiCost/ : berekeningen aan stalen raamwerken
# Scraping PDF link for: "...but some are more equal than others": development of an instrument for software performance prioritization
# Scraping PDF link for: .NL
# Scraping PDF link for: (Ab)using Bitcoin for anti-censorship tool
# Scraping PDF link for: (Bio)chemische eigenschappen van fosfaatgemethyleerd DNA
# Scraping PDF link for: (Bio)chemische eigenschappen van parallelle DNA-duplices gestabiliseerd door polylysine : structuur, stabiliteit, enzymatische herkenbaarheid
# Scraping PDF link for: (C)PO in de gemeentelijke organisatie: het Kavelpaspoort als kritische succesfactor
# Scraping PDF link for: (Co)polymerisatie aan het oppervlak van gemodificeerd titaandioxide
# Scraping PDF link for: (Co)polymerisatie van methylmethacrylaat aan het oppervlak van titaandioxide
# Scraping PDF link for: (Data) refinement calculus met stack voorbeelden
# Scraping PDF link for: (De-)aggregatie in geroerde vaten
# Scraping PDF link for: (De)centrale inkoop èn synergie? bij NBM-Amstelland, Infrastructuur en Milieu: een verslag van een afstudeeronderzoek naar de mogelijkheden tot het realiseren van synergie middels coördinatie binnen een gedecentraliseerde inkooporganisatie
# Scraping PDF link for: (Discrete) strategies for the binary multiplying channel
# Scraping PDF link for: (Door)breekbaar
# Scraping PDF link for: (ei)Land : een zoektocht naar stedenbouw en architectuur : van masterplan tot woningplattegrond
# Scraping PDF link for: (Energiezuinige) bakkerij
# Scraping PDF link for: (Es)sence
# Scraping PDF link for: (Es)sense
# Scraping PDF link for: (Flex)pool: the trigger?: a study to reduce manpower by synchronizing the short-term production schedules of P1L, P1P and P2P, three production plants of Fuji Photo Film BV in Tilburg
# Scraping PDF link for: (Her)gebruikt bouwen: demontage en hergebruik van geprefabriceerde betonelementen van naoorlogse (montage-)systeembouwwoningen
# Scraping PDF link for: (Her-)ontwerp van bedrijfsprocessen: de invloed van veranderprogramma's op bedrijfsprocessen
# Scraping PDF link for: (I)ADL assistive robot for older adults with dementia
# Scraping PDF link for: (In,Ga)N heterostructures in self-assembled GaN nanowires grown on TiN by molecular beam epitaxy
# Scraping PDF link for: (In)security of video surveillance systems in building automation systems
# Scraping PDF link for: (In)visible illusion: architecture for co-existence
# Scraping PDF link for: (Membrane assisted) - sorption enhanced reforming in a dual fluidized bed: an experimental study
# Scraping PDF link for: (Microwave assisted) dynamic kinetic resolution of secondary alcohols
# Scraping PDF link for: (On)gebonden frame: woon/werk omgeving voor de creatieve klasse van Eindhoven binnen een vrij en duurzaam kader
# Scraping PDF link for: (On-)gekoppelde voorraadbeheersing bij ASML te Veldhoven
# Scraping PDF link for: (Photoactive) metathesis polymers
# Scraping PDF link for: (Re)(dis)covering (re)connectivity: a public parkscape - subterranean station for Barcelona
# Scraping PDF link for: (Re)allocation-research at Philips Monitors
# Scraping PDF link for: (Re)defining Neways Advanced Applications' life cycle services offering
# Scraping PDF link for: (re)form block: urban block housing
# Scraping PDF link for: (S)cars: a treatment for Boston's big dig
# Scraping PDF link for: (Semi)automatic quantification of the internal elastic lamina fenestrae in remodeling arteries
# Scraping PDF link for: (Sociale woningbouw)2 : ontwerpfase : het ontwerpen van een milieubewuste en betaalbare seniorenwoning
# Scraping PDF link for: (Structural) identification of a single track truck model
# Scraping PDF link for: (Sustainable) reconstruction of World Heritage property
# Scraping PDF link for: (Ultra-) Small angle X-ray scattering on asphaltenes : mathematical modelling and physical conclusions
# Scraping PDF link for: (Verplichte) samenwerking tussen projectontwikkelaar en aannnemer bij het ontwikkelingsproces: een beslissingsondersteunend model voor de projectontwikkelaar om in de (pré)initiatieffase te toetsen of de 'eigen' aannemer geschikt is om het project te realiseren
# Scraping PDF link for: (Voor-)ontwerp van een transportsysteem voor productstroken
# Scraping PDF link for: [Green H2Ousing]: landstedelijk en autarkisch wonen in de IJsselzone te Zwolle
# Scraping PDF link for: -[S]antoniem: transformatie van tijdelijk naar definitief
# Scraping PDF link for: [Under Dock]: herbestemming van een droogdok tot een nieuwe stedelijke ruimte met pop- en jongerencentrum in de Lisnave scheepswerf in Almada, Portugal
# Scraping PDF link for: {“wdym_data_???”: Exploring data physicalization for learning algorythms in social media
# Scraping PDF link for: $\Gamma \vdash M : ? , \Gamma \vdash M : \tau  ?, \Gamma \vdash ? : \tau$ or synthesis of types and terms for typed lambda calculi
# Scraping PDF link for: &ABLE: Simulating stimuli using haptic feedback to increase accessibility in competitive video games
# Scraping PDF link for: +Jewel: the trigger for narcoleptics
# Scraping PDF link for: µ-Plasma assisted deposition of titanium dioxide thin films
# Scraping page 1...
# Scraping PDF link for: µPlasmaPrinting of amine-containing polymer films using APTMS(3-aminopropyl trimethoxysilane)
# Scraping PDF link for: 0.1 GHz - 35.1 GHz broadband IF down-conversion mixer for 60 GHz fiber-optics receiver
# Scraping PDF link for: 0D lumped approach to incorporate the dynamic part of the pressure at vessel junctions in a 1D wave propagation model
# Scraping PDF link for: 1,1,4,4-Tetramethoxy-2-buteen en 2,5-dimethoxy-2,5-dihydrofuran als uitgangsstof voor de synthese van (hetero)cyclische vicinale biscarbaldehyden . De synthese van methoxy gesubstitueerde alfa-naftolen
# Scraping PDF link for: 1,4,7-triazacyclononane functionalized BTA: a supramolecular polymer for cooperative catalysis
# Scraping PDF link for: 1/f noise as a diagnostic tool, and 1/f noise in the extinction coefficient of optical fibres
# Scraping PDF link for: 1/f noise in ferromagnetic tunnel junctions
# Scraping PDF link for: 1/f-ruis in de thermospanning van intrinsiek germanium
# Scraping PDF link for: 1/f ruis in geleiders en in het Hall-effekt
# Scraping PDF link for: 1/f ruis in laserdiodes
# Scraping PDF link for: 1/f ruis in laserlicht
# Scraping PDF link for: 1/f-ruis in magnetoweerstanden met verschillende lengte/breedte verhoudingen
# Scraping PDF link for: 1/f ruis in MOS-transistoren
# Scraping PDF link for: 1/f ruis in MOS-transistoren
# Scraping PDF link for: 1/f-ruis in P+-N fotodiodes
# Scraping PDF link for: 1/f ruismetingen met behulp van de vierpuntsprobe
# Scraping PDF link for: 1/f ruis van bipolaire transistoren
# Scraping PDF link for: 1+1=3 : een visie op herbestemmen, toegepast op het voormalig Gemeentelijk Lyceum Eindhoven
# Scraping PDF link for: 1 + 1 = één?: afstudeerrapport: integratie bij DeliXL Schiedam en DeliXL Barendrecht
# Scraping PDF link for: "1+1>2?!": Synergiemogelijkheden in de fysieke distributie van DSM op de lokatie Geleen
# Scraping PDF link for: 111 Villa's voor Salman Rushdie : afstudeer-experimenten
# Scraping PDF link for: 123I-produktie via de (P,2N)- en (P,PN)-reactie op 124XE
# Scraping PDF link for: 12 Bit, 250 MSamples/s current steering DAC
# Scraping PDF link for: 13/13 machinefabriek: herbestemming van de machinefabriek te Vlissingen
# Scraping PDF link for: 13C-1H koppelingskonstanten in het cyclopentadienylanion en modellen : meting en MO-berekeningen
# Scraping PDF link for: 14 bit ENOB SAR ADC in 55nm CMOS
# Scraping PDF link for: 19F MRI : methods and applications for quantitative molecular imaging
# Scraping PDF link for: 1 B.O.M. en verder?: prototyping van een stuklijst- en bewerkingensysteem
# Scraping PDF link for: 1 Day 2 4ever : apartment hotel @ Westside Waterfront Manhattan
# Scraping PDF link for: 1D parameter study on tar conversion in counterflow diffusion flames
# Scraping PDF link for: 1D phenomenological model of Propane Aromatization in a Fluidized Bed Reactor
# Scraping PDF link for: 1e aanzet voor een nieuwe hoofd - bibliotheek van de Openbare Bibliotheek Geldrop : programma van eisen
# Scraping PDF link for: 1H-13C Spin-spin interacties in enige alfa,beta- en beta,gamma-enonen en geprotoneerde derivaten
# Scraping PDF link for: 1H NMR conformatie-analyse van gemodificeerde nucleosiden in oplossing : invloed van sterische- en stereo-elektronische effekten op de furanose conformatie
# Scraping PDF link for: 1MORE: architectural design of a new mobile telephony service
# Scraping PDF link for: 2-(2-imidazolyl)acetophenonen : bereiding en toepassingen
# Scraping PDF link for: 2001 : A water oddity : het toepassen van een gemetselde boogconstructie op het ontwerp van een zwembadcomplex
# Scraping PDF link for: 2020: Duurzame energie in de woningbouw: en de rol van Nuon Tecno
# Scraping PDF link for: 21 Century intergenerational cohousing community: Interplay of overlapping spaces in an intergenerational cohousing building in Eindhoven to limit the building footprint and improve quality of life in city centres
# Scraping PDF link for: 2-channel mono playback in cinema and room in room acoustics: the effect of direct field interference on playback quality of diffuse-field recordings
# Scraping PDF link for: 2-class Terror Queue model: Analysis and optimal assignment of agents
# Scraping PDF link for: 2D and 3D capacitance calculations for MOS VLSI
# Scraping PDF link for: 2D Core flow instability in a wide vaneless diffuser: experimental set-up design
# Scraping PDF link for: 2D details en 3D bouwknopen : de ontwikkeling van een NBM-Amstelland modelleersysteem voor 3D bouwknopen op basis van 2D details en vice versa
# Scraping PDF link for: 2D Detection of Carton Boxes from RGB images
# Scraping PDF link for: 2D echocardiography strain inmaging of the supported heart: a first look into the governing parameters of left ventricular function in supported hearts and a pilot study towards a novel cardiovascular echography strain imagining technique
# Scraping PDF link for: 2D Electron thermal transport and electron thermal transport near magnetic islands
# Scraping PDF link for: 2-D flow evolution in bounded domains
# Scraping PDF link for: 2D in-cylinder temperature and fuel distribution measurements using two-color LIF
# Scraping PDF link for: 2D magneto-optical trap as source for cold ions
# Scraping page 2...
# Scraping PDF link for: 2D numerical model of droplet breakup in emulsions: development of a numerical model to predict the number and size after breakup of droplets in simple shear flow
# Scraping PDF link for: 2D perovskite solar cells based on powder and crystal precursors
# Scraping PDF link for: 2D-proeven op lijmwerk: rapportage laboratoriumonderzoek
# Scraping PDF link for: 2 dragers in binnenstad Roosendaal
# Scraping PDF link for: 2D temperature measurements in the EHPC using laser-induced phosphorescence
# Scraping PDF link for: 2-D temperature measurements in water using laser induced fluorescence
# Scraping PDF link for: 2-D temperatuurmetingen met behulp van "laser-induced fluorescence"
# Scraping PDF link for: 2D tracking of coronary arteries in X-ray angiograms over time
# Scraping PDF link for: 2D vascular strain imaging, using plane wave ultrasound
# Scraping PDF link for: 2FACE centrum voor raamprostitutie: een aanpasbaar winkelcentrum
# Scraping PDF link for: 2-Imidazolyl-acetophenonen en -azijnzure ester : bereiding en omzetting naar (1,2)geannelleerde systemen
# Scraping PDF link for: 2-Mind
# Scraping PDF link for: 31P NMR measurement of ATP synthesis flux in skeletal muscle for assessment of mitochondrial function
# Scraping PDF link for: 32% off: shopping for utopia
# Scraping PDF link for: 368C: making stress tangible
# Scraping PDF link for: 3D adaptable building skin: mechanisme onderzoek corpus vivera architectura
# Scraping PDF link for: 3D cache-oblivious multi-scale traversals of meshes using 8-reptile polyhedra
# Scraping PDF link for: 3D Camera Monitoring of Rodent Irradiation Geometry for High Precision Shielding
# Scraping PDF link for: 3D concrete printing: research and development of a structural reinforcement system for 3D printing with concrete
# Scraping PDF link for: 3D concrete printing: The applicability of different characterization methods to determine the mechanical material properties of 3D printable pastes with various aggregates and fibers
# Scraping PDF link for: 3D concrete printing in architecture: a research on the potential benefits of 3D concrete printing in the construction of residential buildings in the Netherlands
# Scraping PDF link for: 3D Face Reconstruction Using Deep Learning
# Scraping PDF link for: 3D face reconstruction using structured light on a hand-held device
# Scraping PDF link for: 3D FE implementation of an incompressible quadriphasic mixture model for large deformations
# Scraping PDF link for: 3D fingerprint detection in ancient museum sculptures from CT data
# Scraping PDF link for: 3D fisheye treemaps
# Scraping PDF link for: 3Dflexmould: development of a self-supporting double curved glass dome
# Scraping PDF link for: 3D flow velocity imaging based on high frame rate ultrasound acquisitions
# Scraping PDF link for: 3-D geometry assessment of lower extremities using multi-perspective, freehand, 2-D ultrasound for improved decision making in peripheral arterial occlusive disease
# Scraping PDF link for: 3D geometry reconstruction based on limited experimental data
# Scraping PDF link for: 3D geometry reconstruction of multi-phase materials with limited experimental data using the Phase Field method
# Scraping PDF link for: 3D graphics rendering for multiview displays
# Scraping PDF link for: 3D-graphics rendering on a multiprocessor architecture
# Scraping PDF link for: 3D human osteoblast - osteoclast in vitro co-culture
# Scraping PDF link for: 3D-Labyrint : een bouwsysteem voor een nieuw klimconcept
# Scraping PDF link for: 3D laxity assessment in ACL-patients
# Scraping PDF link for: 3D map creating using the structured light technique for obstacle avoidance
# Scraping PDF link for: 3D medical image segmentation with labeled and unlabeled data using autoencoders
# Scraping PDF link for: 3D Modelling and validation of boiler emissions using the Flamelet Generated Manifold technique
# Scraping PDF link for: 3D modelling of airflow in the human airways
# Scraping PDF link for: 3D multimodal visualization techniques for tumor resection planning in neurosurgery
# Scraping PDF link for: 3D Object Detection From LiDAR data using Distance Depended Feature Extraction
# Scraping PDF link for: 3D ordered macroporous lithium ion conducting material for application in solid state batteries
# Scraping PDF link for: 3D orientation scores applied to MRA vessel analysis
# Scraping PDF link for: 3D particle tracking velocimetry of particle-laden turbulent pipe flow
# Scraping PDF link for: 3D point cloud reconstruction from photographs using a spring embedder algorithm
# Scraping PDF link for: 3D-printed electrodes for redox flow batteries
# Scraping PDF link for: 3D printed façade panel
# Scraping PDF link for: 3D printing as an emerging general purpose technology: opportunities & challenges
# Scraping PDF link for: 3D printing of concrete structures
# Scraping page 3...
# Scraping PDF link for: 3D printing of microfluidic chips with different modules for point-of-care testing applications
# Scraping PDF link for: 3D Printing of Polymer-Derived Ceramics
# Scraping PDF link for: 3D PTV applied to a viscous flow in a cylindrical domain
# Scraping PDF link for: 3D quantification of lumbar spinal dynamics at the time of surgery
# Scraping PDF link for: 3D reconstruction and analysis of branching streamer discharges: elementary processes in gas discharges
# Scraping PDF link for: 3D reconstruction of coronary artery centerlines from two 2D angiography-based planar projections
# Scraping PDF link for: 3D reconstruction of streamer discharges using mathematical algorithms: based on predictive back-end reconstruction, minimum spanning trees and sub-Riemannian geometry
# Scraping PDF link for: 3D scalar field simulations for Micro Mixing applications in a cylindrical geometry: implementation and verification
# Scraping PDF link for: 3D segmentatie en visualisatie in MR angiografie
# Scraping PDF link for: 3D sensor
# Scraping PDF link for: 3D simulaties van stromingen in geroerde vaten : met behulp van CFDS-Flow3D
# Scraping PDF link for: 3D skin body reconstruction
# Scraping PDF link for: 3D surface reconstruction of environments using point clouds and textures
# Scraping PDF link for: 3D template matching on the GPU
# Scraping PDF link for: 3D thermische modellering van een laagspanningspatroon voor de beveiliging van halfgeleidercomponenten in EMTP
# Scraping PDF link for: 3D-TV signal conversion algorithms and embedded architectures
# Scraping PDF link for: 3ducation: 3d computer learning strategies in spatial design; with as test case ''school design''
# Scraping PDF link for: 3D viewing experience: the induction and measurement of discomfort for stereoscopic content with motion on 3DTVs
# Scraping PDF link for: 3D viscoelastic analysis
# Scraping PDF link for: 3D visual inspection system
# Scraping PDF link for: 3D workpiece reconstruction from 2D images : using top-view cameras
# Scraping PDF link for: 3G introduction in China
# Scraping PDF link for: 3He/4He-mengkoeler met tweevoudige mengkamer
# Scraping PDF link for: 3MO-TION: 3DCP movement and circulation
# Scraping PDF link for: 3-Nitrotyrosine as a marker for oxidative stress caused by inflammatory reactions
# Scraping PDF link for: 3 Ontwerpen
# Scraping PDF link for: 3 Projekten : woonhuis te Stiphout, muziektheater voor Maastricht, woonareaal psychiatrisch centrum
# Scraping PDF link for: 3SGINA
# Scraping PDF link for: 3 woningen, 3 landen, 1 landschap
# Scraping PDF link for: 3 x 3= Het overtreden van de drempel
# Scraping PDF link for: 3 x produktontwikkeling : ontwikkeling vlakblijvende buitendeur, onderzoek dakelementen, ontwerp geodetische bol
# Scraping PDF link for: 43-Gb/s POLMUX-RZ_DPSK vs. 43-Gb/s POLMUX-RZ-DQPSK modulation for the use in long-haul transmission systems
# Scraping PDF link for: 4C-ing customer constraints : analysing the effects of customer requirements on logistics costs and performance for Philips Consumer Electronics' DC Acht
# Scraping PDF link for: 4D -Printing of Photonic Liquid Crystal Elastomers
# Scraping PDF link for: 4-kanaals meetversterker
# Scraping PDF link for: 4 Prijsvragen (en Helmut Jahn)
# Scraping PDF link for: 4 projekten
# Scraping PDF link for: 4 Projekten '83/'84
# Scraping PDF link for: 4-vector correlatiemetingen aan Ne(2P)5(3P)-He botsingen in de Mini-Bundel I opstelling
# Scraping PDF link for: 55+ housing in 2040: insights in the future supply and demand of attractive and appropriate 55+ housing
# Scraping PDF link for: 5-daagse ruwbouwcyclus voor hoogbouwprojecten: een hulpmiddel voor het begeleiden van het calculatieteam bij het ontwerpen van een 5-daagse ruwbouwcyclus voor een hoogbouwproject
# Scraping PDF link for: 5G Business models: Considerations for organizations
# Scraping PDF link for: 5-Hydroxymethylfurfural
# Scraping PDF link for: 5-spiro-gesubstitueerde cyclopentadieeen (1,3)-verbindingen: De synthese, thermolyse en spectrometrische aspecten van spiro[4,4]nonadieen (1,3) en spiro[4,5]decadieen (1,3)
# Scraping PDF link for: 5-spiro-gesubstitueerde cyclopentadieen-2,4 verbindingen : de synthese en thermolyse van 1,1,2,2-tetramethyl spiro(2,4)heptadieen(2',4')
# Scraping PDF link for: 5th Generation district heating and cooling in the Efteling
# Scraping PDF link for: 5x buurtbeheer
# Scraping PDF link for: 60GHz FMCW radar system with high distance and Doppler resolution and accuracy
# Scraping PDF link for: 60 GHz radio module design and implementation of subsystems
# Scraping PDF link for: 60 GHz wireless power transfer - system analysis and Doherty power amplifier design: 4-stage Doherty power amplifier
# Scraping page 4...
# Scraping PDF link for: 6LoWPAN: IPv6 for battery-less building networks
# Scraping PDF link for: 7-8-9: serie die zich contextueel gedraagt
# Scraping PDF link for: 8044 SDLC/HDLC controller
# Scraping PDF link for: 80 kW isolated DC/DC converter for railway applications
# Scraping PDF link for: A_green_house: literatuurstudie : transparant overkapte ruimtes
# Scraping PDF link for: A_topia: living in the clouds
# Scraping PDF link for: A_void block21: ontwerp voor groot stedelijk bouwblok aan de Zuidas, Amsterdam
# Scraping PDF link for: A.P.L. : achtergronden en taalbeschrijving
# Scraping PDF link for: A (max, +) based trade-off exploration between storage and throughput for scenario-aware dataflow
# Scraping PDF link for: A 10-bit folding and interpolating A/D-converter for low-power video applications
# Scraping PDF link for: A 1 MHz wide bandgap power amplifier for high-precision applications
# Scraping PDF link for: A 20 GHz stage differential class B power amplifier with on-chip balun in SiGe QUBIC4X BiCMOS
# Scraping PDF link for: A 21st century Capsule Tower for inner city density
# Scraping PDF link for: A 270 GHz broadband frequency multiplier in 40-nm CMOS
# Scraping PDF link for: A 29Si CP-MAS NMR study of deactivation techniques in capillary gas chromatography
# Scraping PDF link for: A 2-D finite element model of a muscle cell in agarose gel-matrix
# Scraping PDF link for: A 2-dimensional magnetic levitation-system
# Scraping PDF link for: A 2-echelon capacitated location-routing problem for early applications of food distribution network designs
# Scraping PDF link for: A2-kantoortoren te Maastricht : stadspoort van Maastricht
# Scraping PDF link for: A2RID: An Anonymous RemoteID-compliant Group Signature Scheme for Commercial Drones
# Scraping PDF link for: A 3D co-culture model of mesenchymal stem cells and endothelial cells to promote vascularization and osteogenesis in bone tissue engineering
# Scraping PDF link for: A 3-D finite element model of the tibialis anterior muscle of a rat: a contribution to pressure sores research
# Scraping PDF link for: A 3D modeller for implicit surface skeletons
# Scraping PDF link for: A 3-D structural skin model: development and implementation
# Scraping PDF link for: A4 Midden-Delfland : meervoudig ruimtegebruik op het grensvlak van stad, land en infrastructuur
# Scraping PDF link for: A 5bit 1GS/s 2.7mW time-interleaved asynchronous digital slope ADC
# Scraping PDF link for: A 6.65 m Normal Incidence Spectrometer (NIS) for high resolution spectroscopy in the VUV
# Scraping PDF link for: A 60GHz, 12.5 GHz 1dB bandwidth fully integrated power amplifier using a distributed ring transformer in CMOS 65nm
# Scraping PDF link for: A 60 GHz fully integrated power amplifier using a distributed transformer in CMOS 45 nm
# Scraping PDF link for: A 8044 look-a-like SDLC/HDLC controller
# Scraping PDF link for: AAL security and privacy: Transferring XACML policies for end to end access and usage control
# Scraping PDF link for: Aanbevelingen voor de klimatisering van een museum voor scheepsarcheologie
# Scraping PDF link for: Aanbevelingen voor methoden voor het ontwikkelen van telematicasystemen
# Scraping PDF link for: Aanbevelingen voor voorraadbeheersing met betrekking tot "lumpy demand" bij Sikkens
# Scraping PDF link for: Aanbodcreatie proces van recreatief winkelen
# Scraping PDF link for: Aanbouwsysteem voor woningverbetering
# Scraping PDF link for: Aanbrengen van krimpkappen om verschillende typen beeldbuizen met behulp van een universele automaat
# Scraping PDF link for: Aandachtspunten
# Scraping PDF link for: 'Aandacht voor de omgeving': een onderzoek naar de invloed van een combinatie van fysieke en sociale eigenschappen van een omgeving op het restoratieve effect van die omgeving
# Scraping PDF link for: Aandacht voor kwaliteit bij de aanschaf van brandweermaterieel
# Scraping PDF link for: Aandacht voor leverbetrouwbaarheid: noodzaak voor kwaliteit en continuïteit
# Scraping PDF link for: A and B allowables for the 3-p Weibull distribution
# Scraping PDF link for: Aandrijvingen van een 3D-meetmachine
# Scraping PDF link for: Aangepaste produktiesystemen voor de ontwikkelingslanden
# Scraping PDF link for: Aangiftebereidheid van computercriminaliteit bij bedrijven
# Scraping PDF link for: Aan het einde van de Leien: aanvulling op het historisch stadscentrum van Antwerpen
# Scraping PDF link for: Aan hoger wal : villa te Nijmegen . Randverschijnselen : projekt te Den Bosch
# Scraping PDF link for: Aankoopbeleid van fleetowners
# Scraping PDF link for: Aankopen en verbeteren in de gemeente Utrecht : financieel-economische evaluatie van zes jaar praktijk met het stadsvernieuwings-instrument aankopen en verbeteren
# Scraping PDF link for: Aanloopkosten in productprojecten : onderzoek naar reductie- en beheersingsmogelijkheden
# Scraping page 5...
# Scraping PDF link for: Aanloopverschijnselen van de synchrone motor
# Scraping PDF link for: Aan normen waarde(n) hechten: het gebruik van normen en prestatie-beoordeling bij de produktiebesturing van het Grafisch Bedrijf
# Scraping PDF link for: Aanpak scheefwoners: strategieanalyse voor de omgang met scheefwoners in het Stedelijk Gebied Eindhoven
# Scraping PDF link for: Aanpak verbeteringsprojecten en ontwikkeling management van verbeteringen bij de EED
# Scraping PDF link for: Aanpasbaarheid van bestaande draagconstructies in het kader van duurzaam bouwen
# Scraping PDF link for: Aanpasbaarheid van de draagconstructie: onderzoek naar de haalbaarheid en ontwerp van verplaatsbare kolommen in een draagconstructie
# Scraping PDF link for: Aanpasbaarheid van woningen: een onderzoek naar indicatoren voor aanpasbaarheid van woningen in het kader van duurzaamheid
# Scraping PDF link for: Aanpasbaarheid van woningen . Analyse Tivoli
# Scraping PDF link for: Aanpasbaar wonen . Wonen naar maat
# Scraping PDF link for: Aanpasbaar woonmilieu : van theorie naar praktijk(?)
# Scraping PDF link for: Aanpassen aan de groei: het ontwerp van een jaarproductieplanning
# Scraping PDF link for: Aanpassingen aan bloedsuikermeetapparatuur t.b.v. visueel gehandicapte diabetici
# Scraping PDF link for: Aanpassingen aan de 124Xe-bestralingsopstelling voor routinematige produktie van 123I op de THE
# Scraping PDF link for: Aanpassingen aan een model en inleidende metingen aan een testopstelling voor een hoogvermogen pulsbuis
# Scraping PDF link for: Aanpassing en ontwerp van een injecteermachine
# Scraping PDF link for: Aanpassingen van een proefopstelling van een optisch abonnee systeem
# Scraping PDF link for: Aanpassing van een automatische meetopstelling voor ultrasone tomografie aan de IEEE-488 bus
# Scraping PDF link for: Aanpassing van het software pakket "VISION" aan de frame grabber DT2861 van Data Translation
# Scraping PDF link for: Aanschaf van reservedelen: een vergelijk van vijf modellen binnen de Defensie Materieel Organisatie toegepast op single en multi-echelon praktijksituaties
# Scraping PDF link for: Aansluiting school-bedrijf : ontwikkeling en toetsing van een methode van onderzoek
# Scraping PDF link for: Aansluitingsproblemen bij wiskunde: de overgang van het vwo naar de technische universiteit
# Scraping PDF link for: Aansluitingsproblemen met wiskunde bij eerstejaarsstudenten van de TUE
# Scraping PDF link for: Aansprakelijkheid en logistiek: een onderzoek in Ziekenhuis Rijnstate naar de logistiek van steriele disposables mede in relatie tot de nieuwe aansprakelijkheidswetgeving
# Scraping PDF link for: Aanstroomproblemen van grote gefluidiseerde bedden
# Scraping PDF link for: Aansturing van distributieknooppunten met electronic data interchange
# Scraping PDF link for: Aansturing van lineaire akoestische array's voor ultrasone transmissie tomografie
# Scraping PDF link for: Aansturing van motoronderhoudsprojecten bij Maintenance Unit CF6
# Scraping PDF link for: Aantrekkelijke produktgroepen voor Roll-fed labeling en het verkoop analyse model
# Scraping PDF link for: Aanvang van het onderzoek naar de optimale afscheiding van olienevels in een kontinu proces aan draad- en vezel-pakketten en poreuse polymeren bij een minimale drukval
# Scraping PDF link for: Aanvoerstromen geanalyseerd: een vergeten kostenpost?
# Scraping PDF link for: Aanvoer van bloemen en planten: de wachtrijproblematiek
# Scraping PDF link for: Aan wat vooraf ging: een analoge interventie bij een bestaand gebouw
# Scraping PDF link for: Aanzet marktwaardebepaling zorgvastgoed: een onderzoek naar het bepalen van de marktwaarde van het verpleeghuis binnen de verpleging en verzorgingssector
# Scraping PDF link for: Aanzetten tot uitzetten: een onderzoek naar de mogelijkheden om het huishoudelijk stand-by verbruik terug te dringen
# Scraping PDF link for: Aanzet tot businessplan Philips Transport en Expeditie B.V.
# Scraping PDF link for: Aanzet tot de implementatie van een Ethernet verbinding tussen de Intel 310 en de THE KUNix machine
# Scraping PDF link for: Aanzet tot de ontwikkeling van een betere procesbeheersing
# Scraping PDF link for: Aanzet tot de ontwikkeling van een informatiesysteem voor het werken met Markov-modellen
# Scraping PDF link for: Aanzet tot de produktie en de detectie van metastabiel helium bij temperaturen van 0,05 tot 4,2 K
# Scraping PDF link for: Aanzet tot de structurering van de marketing informatie voor Philips' telecommunicatie industrie
# Scraping PDF link for: Aanzet tot een analyse- en waarderingsmethode voor oude stadsgebieden
# Scraping PDF link for: Aanzet tot een decision support system voor stedelijke vernieuwingsprojecten : Utrecht City Project als referentie project
# Scraping PDF link for: Aanzet tot een digitale real-time simulator voor transienten in netten
# Scraping PDF link for: Aanzet tot een geintegreerde MOST audioversterker
# Scraping PDF link for: Aanzet tot een handleiding voor instellingsplanning ten behoeve van instellingen voor algemeen maatschappelijk werk
# Scraping PDF link for: Aanzet tot een M.I.S. en uitwerking van het informatiesysteem onderwijs
# Scraping PDF link for: Aanzet tot een nieuwe bereidingswijze van DNA-achtige molekulen
# Scraping PDF link for: Aanzet tot een nieuw LCA-model voor gebouwen: theoretische en praktische knelpunten in de levenscyclusanalyse voor gebouwen en de zwaartepunten in het milieuprofiel van woningen
# Scraping PDF link for: Aanzet tot een ontwerp van een kostenanalysesysteem ten behoeve van de logistiek
# Scraping PDF link for: Aanzet tot een praktijk richtlijn kwaliteitsborging van de voedingsverzorging in instellingen
# Scraping page 6...
# Scraping PDF link for: Aanzet tot een systeem voor de generatie van snijpatronen in een plaatwerkbedrijf
# Scraping PDF link for: Aanzet tot een taal waarmee bouwkundige artefacten kunnen worden beschreven
# Scraping PDF link for: Aanzet tot het karakteriseren van het relaxatiegedrag van HP-PE vezels met behulp van het 1 dimensionaal schapery relaxatie model : tussenrapport
# Scraping PDF link for: Aanzet tot het ontwerpen van een bloedvatdiameter-meter
# Scraping PDF link for: Aanzet tot het ontwerp van een informatiesysteem voor het werken met Markov-modellen
# Scraping PDF link for: Aanzet tot het ontwerp van een logistieke structuur voor de afdeling Distributie van de NV PNEM
# Scraping PDF link for: Aanzet tot het ontwerp van een probleemklassifikatie
# Scraping PDF link for: Aanzet tot het ontwerp van een produktiebesturingssysteem
# Scraping PDF link for: Aanzet tot kwaliteitsverbetering bij Multisol Raambekleding BV
# Scraping PDF link for: Aanzet tot kwaliteitsverbetering van veelpolige miniatuurmagneten
# Scraping PDF link for: Aanzet tot mogelijke instrumentatie van de diameterbepaling van een bloedvat m.b.v. frequentie-gemoduleerd ultrageluid
# Scraping PDF link for: Aanzet tot simultane meting van magnetische susceptibiliteit en elektrische geleidbaarheid met SQUID-gradiometer-opstelling
# Scraping PDF link for: Aanzet tot toekomstige layout
# Scraping PDF link for: Aanzet voor een softwarepakket ter analyse van de afwijkingenstructuur van meerassige machines
# Scraping PDF link for: Aardbevingen en de Dubai Tower : een literatuurstudie naar aardbevingen en een dynamische responsieberekening van de Dubai Tower uitgevoerd met het computerprogramma M.V.S.
# Scraping PDF link for: Aardtunnel-ventilatie : koelen en (voor)verwarmen van ventilatielucht door uitwisseling en opslag van warmte in de bodem
# Scraping PDF link for: A basis for the order-to-order method: theory and validation
# Scraping PDF link for: Abattoirs d'Anderlecht: restoring the symbolic value of a propelling monument
# Scraping PDF link for: ABCB1 variants in association with clopidogrel response
# Scraping PDF link for: ABC cycle counting: een raamwerk om voorraadgegevens nauwkeurig te krijgen én te houden
# Scraping PDF link for: A BDD based prover for mCRL2
# Scraping PDF link for: Abdominal aortic aneurysms : a numerical/experimental approach
# Scraping PDF link for: A behavioral model for rationing : decision rules with situational bounds to incentivize forecasting performance in an integrated planning environment: a case study: designing the allocation planning process for Hilti's internal end-to-end supply chain
# Scraping PDF link for: A benchmark set for process discovery algorithms
# Scraping PDF link for: A better interface for automated program transformation
# Scraping PDF link for: A better world for Orphans: Creating a healthy living environment for orphans where a future can be worked on
# Scraping PDF link for: A Bijlmer experience: de Bijlmerroute als verbindend ruimtelijk en programmatisch element in de Bijlmer
# Scraping PDF link for: A billboardshelter in Dar es Salaam
# Scraping PDF link for: A BIM-integrated approach to construction quality management: enabling information and knowledge management during the execution phase of a project life cycle
# Scraping PDF link for: Ab-initio insights into the tunability of the electronic structure in transition metal dichalcogenide alloys grown by atomic layer deposition
# Scraping PDF link for: A biomechanical view on atrial fibrillation: feasibility of stretch-activated ectopic beats in the left atrium
# Scraping PDF link for: A blockchain-based supply chain contract: an analysis to the development of a supply chain contract on a blockchain
# Scraping PDF link for: A Blueprint for Reverse Logistics in the High-Tech OEM Industry: Design of a Reference Architecture using an Enterprise Modeling Approach
# Scraping PDF link for: A body-contact-free respiration sensor in magnetic resonance imaging
# Scraping PDF link for: A bottum-up approach for modeling the performance of partially shaded PV systems with power optimizers
# Scraping PDF link for: A boundary element method for microscopic Stokes flow in deep drawing processes
# Scraping PDF link for: About the synthesis and analysis of encapsulated salt hydrates as PCM-slurry
# Scraping PDF link for: Above the chaos
# Scraping PDF link for: A brain chip to investigate neurite outgrowth by trapping cell-laden hydrogel beads in microsieves
# Scraping PDF link for: A brain-computer interface for walking using EEG
# Scraping PDF link for: A branching process on a hypercubic lattice
# Scraping PDF link for: Abrasive wear of ethylene-octene copolymers and blends of these materials with high density polyethylene in relation to various physical properties
# Scraping PDF link for: A breathtaking journey
# Scraping PDF link for: A breeding ground for innovation: peer-to-peer assistance in the hybrid model of innovation
# Scraping PDF link for: A brickyard deconstruction: the redevelopment of brickyard 'Elden' & the Meinerswijk landscape
# Scraping PDF link for: A brief encounter with Vincent: the effect on self-compassion from a single interaction with a chatbot that gives or asks for help
# Scraping PDF link for: A brief exploration into divergent series in probability theory
# Scraping PDF link for: A Brief Introduction to Traffic Modelling with a Closer Look at the Nagel-Schreckenberg Model
# Scraping PDF link for: A broadband and high-sensitivity frontend design for UHF RFID tag
# Scraping PDF link for: A broadly applicable red dye doped Luminescent Solar Concentrator photo microreactor
# Scraping page 7...
# Scraping PDF link for: Absolute Atomic Hydrogen Densities in Low Pressure Electron Cyclotron Resonance Plasmas measured using Optical Emission Spectroscopy
# Scraping PDF link for: Absolute botsingsdoorsneden voor argon en krypton
# Scraping PDF link for: Absolute Stress Measurement at the Microscale Using High Resolution Electron Backscatter Diffraction and Focused Ion Beam Ring-core Milling
# Scraping PDF link for: Absorptiecoefficienten van inhomogene magnetoplasma's
# Scraping PDF link for: Absorptie en fluorescentie effecten bij röntgen-spectrometrie
# Scraping PDF link for: Absorptie en reflektiemetingen aan GaSe
# Scraping PDF link for: Absorptiekoeling met behulp van restwarmte bij een drukkerij
# Scraping PDF link for: Absorptie van ethylene in zwavelzure mengsels: een oppervlakte reaktie
# Scraping PDF link for: Absorptie van publiekvlak in schaalmodel nagalmkamer : ontwikkelen van een meetmethode
# Scraping PDF link for: Absorption loss analysis and color tuning of plasmonic phosphor based LEDs
# Scraping PDF link for: Absorption spectra on some metal halide molecules used in HID lamps
# Scraping PDF link for: Absorption spectroscopy of nitric oxide in a volume dielectric barrier discharge
# Scraping PDF link for: Absorption spectroscopy on microwave induced Ar - SiCl4 plasmas
# Scraping PDF link for: Absorption spectroscopy on O2 production in an atmospheric pressure dielectric barrier discharge in CO2
# Scraping PDF link for: Abstracting real-valued parameters in parameterised boolean equation systems
# Scraping PDF link for: Abstract interpretation of concurrent logic programs for analysis of variable sharing
# Scraping PDF link for: Abstraction raising in MLIR
# Scraping PDF link for: Abstraktie van kategorieinformatie
# Scraping PDF link for: Abtstraat Maastricht : een voorstel tot herbebouwing met studentenhuisvesting en gezinswoningen
# Scraping PDF link for: A business case for connecting coffee machines to IoT
# Scraping PDF link for: A business process harmonization approach: using process mining techniques
# Scraping PDF link for: AC/DC power modulation for corona plasma generation
# Scraping PDF link for: AC/DC pulsed power corona
# Scraping PDF link for: Academic technology-driven entrepreneurship: "the design of an entrepreneurship education program at the Eindhoven University of Technology"
# Scraping PDF link for: A calculus for combinational circuits consisting of switches
# Scraping PDF link for: A campus in transition: adapting the Maastricht Health Campus for a future with autonomous transport
# Scraping PDF link for: A cap, fine & reward policy framework: creating energy consciousness and urging residents to save energy?
# Scraping PDF link for: A carbon-coated QCM-based atomic hydrogen sensor for in-situ plasma diagnostics
# Scraping PDF link for: A cardiac finite element model of the left ventricular mechanics: from canine towards human model
# Scraping PDF link for: A case study into increasing warranty costs in the Lighting Electronics industry
# Scraping PDF link for: A case study of reporting business KPIs of gaming data through static and interactive visualizations
# Scraping PDF link for: A Case Study on Performance Degradation of Cooling Coils in the Netherlands
# Scraping PDF link for: A case study on the possibilities and constraints of GIS for urban planning and management in Dar es Salaam
# Scraping PDF link for: A cause-effect diagram to support the management of the financial impact of a supply chain disruption: Disruption Analyses of the Supply Chain due to Corona Virus, based on actual information, with focus on Manufacturing Industry
# Scraping PDF link for: Accelerated deconvolution for radio-astronomical imaging using artificial intelligence
# Scraping PDF link for: Accelerated lifetime determination of IGBT modules
# Scraping PDF link for: Accelerated target capture at a sensor surface by microfluidic stirring with magnetic particles
# Scraping PDF link for: Accelerated Wafer Z-map for layout independent leveling
# Scraping PDF link for: Accelerating a movie recommender system using VirtualCL on a heterogeneous GPU  cluster: big data analysis using distributed accelerators
# Scraping PDF link for: Accelerating and intensifying the development of sustainable building in the Netherlands: analysis of impedients and opportunities through literature and expert interviews
# Scraping PDF link for: Accelerating early strength and stiffness development of a Portland cement-based mortar for 3D printing
# Scraping PDF link for: Accelerating I/O efficient graph algorithms on grid graphs using the GPU
# Scraping PDF link for: Accelerating MRI with a Quiet Wireless Insert Gradient Coil
# Scraping PDF link for: Accelerating Multiphase Computational Fluid Dynamics using Artificial Neural Networks
# Scraping PDF link for: Accelerating SIFT feature extraction with a vector DSP: a feasibility study
# Scraping PDF link for: Accelerating simulations of electromagnetic waves in hot, magnetized fusion plasmas
# Scraping PDF link for: Accelerating the binding of microparticle-labeled biomarker proteins to a reactive surface for magnetic particle-based sensors
# Scraping PDF link for: Accelerating the energy transition through intermediary management of high-growth energy firms
# Scraping PDF link for: Accelerating the learning curve at ASML: the effect of increased opportunities to learn
# Scraping PDF link for: Accelerating the learning curve at ASML: an exploration of drivers
# Scraped 400 theses in total.

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# Base URL of the thesis list and PDF files
base_url = "https://research.tue.nl"

# Function to scrape a single page for thesis titles and URLs
def scrape_page(page_num):
    thesis_page_url = f"{base_url}/en/studentTheses/"
    params = {
        'organisationIds': '49ca0778-93f6-4b7f-95be-d4cbfb3be718',
        'nofollow': 'true',
        'type': '/dk/atira/pure/studentthesis/studentthesistypes/studentthesis/master',
        'page': page_num
    }

    response = requests.get(thesis_page_url, params=params)
    soup = BeautifulSoup(response.text, 'html.parser')
    theses = soup.find_all('div', class_='rendering_studentthesis_short')

    thesis_data = []
    for thesis in theses:
        title_tag = thesis.find('h3', class_='title').find('a')
        title = title_tag.get_text(strip=True)
        link = title_tag['href']
        full_link = base_url + link if not link.startswith('http') else link
        thesis_data.append({
            "Title": title,
            "URL": full_link
        })
    
    return thesis_data

# Function to scrape the detailed thesis page
def scrape_thesis_details(thesis_url):
    response = requests.get(thesis_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Get the PDF link
    documents_section = soup.find('div', class_='documents')
    pdf_link = None
    if documents_section:
        pdf_link_tag = documents_section.find('a', class_='link')
        if pdf_link_tag and pdf_link_tag.get('href').endswith('.pdf'):
            pdf_relative_url = pdf_link_tag['href']
            pdf_link = base_url + pdf_relative_url

    # Get supervisors
    supervisors = []
    properties_table = soup.find('table', class_='properties')
    if properties_table:
        supervisor_th = properties_table.find('th', string=lambda text: text and 'Supervisor' in text)
        if supervisor_th:
            supervisor_row = supervisor_th.parent
            supervisors_td = supervisor_row.find('td')
            if supervisors_td:
                supervisor_tags = supervisors_td.find_all('a', class_='link person')
                for tag in supervisor_tags:
                    supervisors.append(tag.get_text(strip=True))

    return pdf_link, supervisors


# Function to scrape all pages and get thesis titles, URLs, PDF links, and supervisors
def scrape_all_theses():
    all_theses = []
    for page_num in range(8):  # 0 to 7 pages
        print(f"Scraping page {page_num}...")
        theses = scrape_page(page_num)
        
        for thesis in theses:
            print(f"Scraping details for: {thesis['Title']}")
            pdf_link, supervisors = scrape_thesis_details(thesis['URL'])
            thesis["PDF"] = pdf_link  # Add the PDF link to the JSON entry
            thesis["Supervisors"] = supervisors  # Add supervisors to the JSON entry
            time.sleep(1)  # Be nice to the server and add a delay

        all_theses.extend(theses)
    
    # Save all theses data to a JSON file
    with open('thesis_titles_links_and_pdfs_and_supervisors.json', 'w', encoding='utf-8') as f:
        json.dump(all_theses, f, ensure_ascii=False, indent=4)

    print(f"Scraped {len(all_theses)} theses in total.")

# Run the scraper
scrape_all_theses()
# Out:
# Scraping page 0...
# Scraping details for: /JoiCost/ : berekeningen aan stalen raamwerken
# Scraping details for: "...but some are more equal than others": development of an instrument for software performance prioritization
# Scraping details for: .NL
# Scraping details for: (Ab)using Bitcoin for anti-censorship tool
# Scraping details for: (Bio)chemische eigenschappen van fosfaatgemethyleerd DNA
# Scraping details for: (Bio)chemische eigenschappen van parallelle DNA-duplices gestabiliseerd door polylysine : structuur, stabiliteit, enzymatische herkenbaarheid
# Scraping details for: (C)PO in de gemeentelijke organisatie: het Kavelpaspoort als kritische succesfactor
# Scraping details for: (Co)polymerisatie aan het oppervlak van gemodificeerd titaandioxide
# Scraping details for: (Co)polymerisatie van methylmethacrylaat aan het oppervlak van titaandioxide
# Scraping details for: (Data) refinement calculus met stack voorbeelden
# Scraping details for: (De-)aggregatie in geroerde vaten
# Scraping details for: (De)centrale inkoop èn synergie? bij NBM-Amstelland, Infrastructuur en Milieu: een verslag van een afstudeeronderzoek naar de mogelijkheden tot het realiseren van synergie middels coördinatie binnen een gedecentraliseerde inkooporganisatie
# Scraping details for: (Discrete) strategies for the binary multiplying channel
# Scraping details for: (Door)breekbaar
# Scraping details for: (ei)Land : een zoektocht naar stedenbouw en architectuur : van masterplan tot woningplattegrond
# Scraping details for: (Energiezuinige) bakkerij
# Scraping details for: (Es)sence
# Scraping details for: (Es)sense
# Scraping details for: (Flex)pool: the trigger?: a study to reduce manpower by synchronizing the short-term production schedules of P1L, P1P and P2P, three production plants of Fuji Photo Film BV in Tilburg
# Scraping details for: (Her)gebruikt bouwen: demontage en hergebruik van geprefabriceerde betonelementen van naoorlogse (montage-)systeembouwwoningen
# Scraping details for: (Her-)ontwerp van bedrijfsprocessen: de invloed van veranderprogramma's op bedrijfsprocessen
# Scraping details for: (I)ADL assistive robot for older adults with dementia
# Scraping details for: (In,Ga)N heterostructures in self-assembled GaN nanowires grown on TiN by molecular beam epitaxy
# Scraping details for: (In)security of video surveillance systems in building automation systems
# Scraping details for: (In)visible illusion: architecture for co-existence
# Scraping details for: (Membrane assisted) - sorption enhanced reforming in a dual fluidized bed: an experimental study
# Scraping details for: (Microwave assisted) dynamic kinetic resolution of secondary alcohols
# Scraping details for: (On)gebonden frame: woon/werk omgeving voor de creatieve klasse van Eindhoven binnen een vrij en duurzaam kader
# Scraping details for: (On-)gekoppelde voorraadbeheersing bij ASML te Veldhoven
# Scraping details for: (Photoactive) metathesis polymers
# Scraping details for: (Re)(dis)covering (re)connectivity: a public parkscape - subterranean station for Barcelona
# Scraping details for: (Re)allocation-research at Philips Monitors
# Scraping details for: (Re)defining Neways Advanced Applications' life cycle services offering
# Scraping details for: (re)form block: urban block housing
# Scraping details for: (S)cars: a treatment for Boston's big dig
# Scraping details for: (Semi)automatic quantification of the internal elastic lamina fenestrae in remodeling arteries
# Scraping details for: (Sociale woningbouw)2 : ontwerpfase : het ontwerpen van een milieubewuste en betaalbare seniorenwoning
# Scraping details for: (Structural) identification of a single track truck model
# Scraping details for: (Sustainable) reconstruction of World Heritage property
# Scraping details for: (Ultra-) Small angle X-ray scattering on asphaltenes : mathematical modelling and physical conclusions
# Scraping details for: (Verplichte) samenwerking tussen projectontwikkelaar en aannnemer bij het ontwikkelingsproces: een beslissingsondersteunend model voor de projectontwikkelaar om in de (pré)initiatieffase te toetsen of de 'eigen' aannemer geschikt is om het project te realiseren
# Scraping details for: (Voor-)ontwerp van een transportsysteem voor productstroken
# Scraping details for: [Green H2Ousing]: landstedelijk en autarkisch wonen in de IJsselzone te Zwolle
# Scraping details for: -[S]antoniem: transformatie van tijdelijk naar definitief
# Scraping details for: [Under Dock]: herbestemming van een droogdok tot een nieuwe stedelijke ruimte met pop- en jongerencentrum in de Lisnave scheepswerf in Almada, Portugal
# Scraping details for: {“wdym_data_???”: Exploring data physicalization for learning algorythms in social media
# Scraping details for: $\Gamma \vdash M : ? , \Gamma \vdash M : \tau  ?, \Gamma \vdash ? : \tau$ or synthesis of types and terms for typed lambda calculi
# Scraping details for: &ABLE: Simulating stimuli using haptic feedback to increase accessibility in competitive video games
# Scraping details for: +Jewel: the trigger for narcoleptics
# Scraping details for: µ-Plasma assisted deposition of titanium dioxide thin films
# Scraping page 1...
# Scraping details for: µPlasmaPrinting of amine-containing polymer films using APTMS(3-aminopropyl trimethoxysilane)
# Scraping details for: 0.1 GHz - 35.1 GHz broadband IF down-conversion mixer for 60 GHz fiber-optics receiver
# Scraping details for: 0D lumped approach to incorporate the dynamic part of the pressure at vessel junctions in a 1D wave propagation model
# Scraping details for: 1,1,4,4-Tetramethoxy-2-buteen en 2,5-dimethoxy-2,5-dihydrofuran als uitgangsstof voor de synthese van (hetero)cyclische vicinale biscarbaldehyden . De synthese van methoxy gesubstitueerde alfa-naftolen
# Scraping details for: 1,4,7-triazacyclononane functionalized BTA: a supramolecular polymer for cooperative catalysis
# Scraping details for: 1/f noise as a diagnostic tool, and 1/f noise in the extinction coefficient of optical fibres
# Scraping details for: 1/f noise in ferromagnetic tunnel junctions
# Scraping details for: 1/f-ruis in de thermospanning van intrinsiek germanium
# Scraping details for: 1/f ruis in geleiders en in het Hall-effekt
# Scraping details for: 1/f ruis in laserdiodes
# Scraping details for: 1/f ruis in laserlicht
# Scraping details for: 1/f-ruis in magnetoweerstanden met verschillende lengte/breedte verhoudingen
# Scraping details for: 1/f ruis in MOS-transistoren
# Scraping details for: 1/f ruis in MOS-transistoren
# Scraping details for: 1/f-ruis in P+-N fotodiodes
# Scraping details for: 1/f ruismetingen met behulp van de vierpuntsprobe
# Scraping details for: 1/f ruis van bipolaire transistoren
# Scraping details for: 1+1=3 : een visie op herbestemmen, toegepast op het voormalig Gemeentelijk Lyceum Eindhoven
# Scraping details for: 1 + 1 = één?: afstudeerrapport: integratie bij DeliXL Schiedam en DeliXL Barendrecht
# Scraping details for: "1+1>2?!": Synergiemogelijkheden in de fysieke distributie van DSM op de lokatie Geleen
# Scraping details for: 111 Villa's voor Salman Rushdie : afstudeer-experimenten
# Scraping details for: 123I-produktie via de (P,2N)- en (P,PN)-reactie op 124XE
# Scraping details for: 12 Bit, 250 MSamples/s current steering DAC
# Scraping details for: 13/13 machinefabriek: herbestemming van de machinefabriek te Vlissingen
# Scraping details for: 13C-1H koppelingskonstanten in het cyclopentadienylanion en modellen : meting en MO-berekeningen
# Scraping details for: 14 bit ENOB SAR ADC in 55nm CMOS
# Scraping details for: 19F MRI : methods and applications for quantitative molecular imaging
# Scraping details for: 1 B.O.M. en verder?: prototyping van een stuklijst- en bewerkingensysteem
# Scraping details for: 1 Day 2 4ever : apartment hotel @ Westside Waterfront Manhattan
# Scraping details for: 1D parameter study on tar conversion in counterflow diffusion flames
# Scraping details for: 1D phenomenological model of Propane Aromatization in a Fluidized Bed Reactor
# Scraping details for: 1e aanzet voor een nieuwe hoofd - bibliotheek van de Openbare Bibliotheek Geldrop : programma van eisen
# Scraping details for: 1H-13C Spin-spin interacties in enige alfa,beta- en beta,gamma-enonen en geprotoneerde derivaten
# Scraping details for: 1H NMR conformatie-analyse van gemodificeerde nucleosiden in oplossing : invloed van sterische- en stereo-elektronische effekten op de furanose conformatie
# Scraping details for: 1MORE: architectural design of a new mobile telephony service
# Scraping details for: 2-(2-imidazolyl)acetophenonen : bereiding en toepassingen
# Scraping details for: 2001 : A water oddity : het toepassen van een gemetselde boogconstructie op het ontwerp van een zwembadcomplex
# Scraping details for: 2020: Duurzame energie in de woningbouw: en de rol van Nuon Tecno
# Scraping details for: 21 Century intergenerational cohousing community: Interplay of overlapping spaces in an intergenerational cohousing building in Eindhoven to limit the building footprint and improve quality of life in city centres
# Scraping details for: 2-channel mono playback in cinema and room in room acoustics: the effect of direct field interference on playback quality of diffuse-field recordings
# Scraping details for: 2-class Terror Queue model: Analysis and optimal assignment of agents
# Scraping details for: 2D and 3D capacitance calculations for MOS VLSI
# Scraping details for: 2D Core flow instability in a wide vaneless diffuser: experimental set-up design
# Scraping details for: 2D details en 3D bouwknopen : de ontwikkeling van een NBM-Amstelland modelleersysteem voor 3D bouwknopen op basis van 2D details en vice versa
# Scraping details for: 2D Detection of Carton Boxes from RGB images
# Scraping details for: 2D echocardiography strain inmaging of the supported heart: a first look into the governing parameters of left ventricular function in supported hearts and a pilot study towards a novel cardiovascular echography strain imagining technique
# Scraping details for: 2D Electron thermal transport and electron thermal transport near magnetic islands
# Scraping details for: 2-D flow evolution in bounded domains
# Scraping details for: 2D in-cylinder temperature and fuel distribution measurements using two-color LIF
# Scraping details for: 2D magneto-optical trap as source for cold ions
# Scraping page 2...
# Scraping details for: 2D numerical model of droplet breakup in emulsions: development of a numerical model to predict the number and size after breakup of droplets in simple shear flow
# Scraping details for: 2D perovskite solar cells based on powder and crystal precursors
# Scraping details for: 2D-proeven op lijmwerk: rapportage laboratoriumonderzoek
# Scraping details for: 2 dragers in binnenstad Roosendaal
# Scraping details for: 2D temperature measurements in the EHPC using laser-induced phosphorescence
# Scraping details for: 2-D temperature measurements in water using laser induced fluorescence
# Scraping details for: 2-D temperatuurmetingen met behulp van "laser-induced fluorescence"
# Scraping details for: 2D tracking of coronary arteries in X-ray angiograms over time
# Scraping details for: 2D vascular strain imaging, using plane wave ultrasound
# Scraping details for: 2FACE centrum voor raamprostitutie: een aanpasbaar winkelcentrum
# Scraping details for: 2-Imidazolyl-acetophenonen en -azijnzure ester : bereiding en omzetting naar (1,2)geannelleerde systemen
# Scraping details for: 2-Mind
# Scraping details for: 31P NMR measurement of ATP synthesis flux in skeletal muscle for assessment of mitochondrial function
# Scraping details for: 32% off: shopping for utopia
# Scraping details for: 368C: making stress tangible
# Scraping details for: 3D adaptable building skin: mechanisme onderzoek corpus vivera architectura
# Scraping details for: 3D cache-oblivious multi-scale traversals of meshes using 8-reptile polyhedra
# Scraping details for: 3D Camera Monitoring of Rodent Irradiation Geometry for High Precision Shielding
# Scraping details for: 3D concrete printing: research and development of a structural reinforcement system for 3D printing with concrete
# Scraping details for: 3D concrete printing: The applicability of different characterization methods to determine the mechanical material properties of 3D printable pastes with various aggregates and fibers
# Scraping details for: 3D concrete printing in architecture: a research on the potential benefits of 3D concrete printing in the construction of residential buildings in the Netherlands
# Scraping details for: 3D Face Reconstruction Using Deep Learning
# Scraping details for: 3D face reconstruction using structured light on a hand-held device
# Scraping details for: 3D FE implementation of an incompressible quadriphasic mixture model for large deformations
# Scraping details for: 3D fingerprint detection in ancient museum sculptures from CT data
# Scraping details for: 3D fisheye treemaps
# Scraping details for: 3Dflexmould: development of a self-supporting double curved glass dome
# Scraping details for: 3D flow velocity imaging based on high frame rate ultrasound acquisitions
# Scraping details for: 3-D geometry assessment of lower extremities using multi-perspective, freehand, 2-D ultrasound for improved decision making in peripheral arterial occlusive disease
# Scraping details for: 3D geometry reconstruction based on limited experimental data
# Scraping details for: 3D geometry reconstruction of multi-phase materials with limited experimental data using the Phase Field method
# Scraping details for: 3D graphics rendering for multiview displays
# Scraping details for: 3D-graphics rendering on a multiprocessor architecture
# Scraping details for: 3D human osteoblast - osteoclast in vitro co-culture
# Scraping details for: 3D-Labyrint : een bouwsysteem voor een nieuw klimconcept
# Scraping details for: 3D laxity assessment in ACL-patients
# Scraping details for: 3D map creating using the structured light technique for obstacle avoidance
# Scraping details for: 3D medical image segmentation with labeled and unlabeled data using autoencoders
# Scraping details for: 3D Modelling and validation of boiler emissions using the Flamelet Generated Manifold technique
# Scraping details for: 3D modelling of airflow in the human airways
# Scraping details for: 3D multimodal visualization techniques for tumor resection planning in neurosurgery
# Scraping details for: 3D Object Detection From LiDAR data using Distance Depended Feature Extraction
# Scraping details for: 3D ordered macroporous lithium ion conducting material for application in solid state batteries
# Scraping details for: 3D orientation scores applied to MRA vessel analysis
# Scraping details for: 3D particle tracking velocimetry of particle-laden turbulent pipe flow
# Scraping details for: 3D point cloud reconstruction from photographs using a spring embedder algorithm
# Scraping details for: 3D-printed electrodes for redox flow batteries
# Scraping details for: 3D printed façade panel
# Scraping details for: 3D printing as an emerging general purpose technology: opportunities & challenges
# Scraping details for: 3D printing of concrete structures
# Scraping page 3...
# Scraping details for: 3D printing of microfluidic chips with different modules for point-of-care testing applications
# Scraping details for: 3D Printing of Polymer-Derived Ceramics
# Scraping details for: 3D PTV applied to a viscous flow in a cylindrical domain
# Scraping details for: 3D quantification of lumbar spinal dynamics at the time of surgery
# Scraping details for: 3D reconstruction and analysis of branching streamer discharges: elementary processes in gas discharges
# Scraping details for: 3D reconstruction of coronary artery centerlines from two 2D angiography-based planar projections
# Scraping details for: 3D reconstruction of streamer discharges using mathematical algorithms: based on predictive back-end reconstruction, minimum spanning trees and sub-Riemannian geometry
# Scraping details for: 3D scalar field simulations for Micro Mixing applications in a cylindrical geometry: implementation and verification
# Scraping details for: 3D segmentatie en visualisatie in MR angiografie
# Scraping details for: 3D sensor
# Scraping details for: 3D simulaties van stromingen in geroerde vaten : met behulp van CFDS-Flow3D
# Scraping details for: 3D skin body reconstruction
# Scraping details for: 3D surface reconstruction of environments using point clouds and textures
# Scraping details for: 3D template matching on the GPU
# Scraping details for: 3D thermische modellering van een laagspanningspatroon voor de beveiliging van halfgeleidercomponenten in EMTP
# Scraping details for: 3D-TV signal conversion algorithms and embedded architectures
# Scraping details for: 3ducation: 3d computer learning strategies in spatial design; with as test case ''school design''
# Scraping details for: 3D viewing experience: the induction and measurement of discomfort for stereoscopic content with motion on 3DTVs
# Scraping details for: 3D viscoelastic analysis
# Scraping details for: 3D visual inspection system
# Scraping details for: 3D workpiece reconstruction from 2D images : using top-view cameras
# Scraping details for: 3G introduction in China
# Scraping details for: 3He/4He-mengkoeler met tweevoudige mengkamer
# Scraping details for: 3MO-TION: 3DCP movement and circulation
# Scraping details for: 3-Nitrotyrosine as a marker for oxidative stress caused by inflammatory reactions
# Scraping details for: 3 Ontwerpen
# Scraping details for: 3 Projekten : woonhuis te Stiphout, muziektheater voor Maastricht, woonareaal psychiatrisch centrum
# Scraping details for: 3SGINA
# Scraping details for: 3 woningen, 3 landen, 1 landschap
# Scraping details for: 3 x 3= Het overtreden van de drempel
# Scraping details for: 3 x produktontwikkeling : ontwikkeling vlakblijvende buitendeur, onderzoek dakelementen, ontwerp geodetische bol
# Scraping details for: 43-Gb/s POLMUX-RZ_DPSK vs. 43-Gb/s POLMUX-RZ-DQPSK modulation for the use in long-haul transmission systems
# Scraping details for: 4C-ing customer constraints : analysing the effects of customer requirements on logistics costs and performance for Philips Consumer Electronics' DC Acht
# Scraping details for: 4D -Printing of Photonic Liquid Crystal Elastomers
# Scraping details for: 4-kanaals meetversterker
# Scraping details for: 4 Prijsvragen (en Helmut Jahn)
# Scraping details for: 4 projekten
# Scraping details for: 4 Projekten '83/'84
# Scraping details for: 4-vector correlatiemetingen aan Ne(2P)5(3P)-He botsingen in de Mini-Bundel I opstelling
# Scraping details for: 55+ housing in 2040: insights in the future supply and demand of attractive and appropriate 55+ housing
# Scraping details for: 5-daagse ruwbouwcyclus voor hoogbouwprojecten: een hulpmiddel voor het begeleiden van het calculatieteam bij het ontwerpen van een 5-daagse ruwbouwcyclus voor een hoogbouwproject
# Scraping details for: 5G Business models: Considerations for organizations
# Scraping details for: 5-Hydroxymethylfurfural
# Scraping details for: 5-spiro-gesubstitueerde cyclopentadieeen (1,3)-verbindingen: De synthese, thermolyse en spectrometrische aspecten van spiro[4,4]nonadieen (1,3) en spiro[4,5]decadieen (1,3)
# Scraping details for: 5-spiro-gesubstitueerde cyclopentadieen-2,4 verbindingen : de synthese en thermolyse van 1,1,2,2-tetramethyl spiro(2,4)heptadieen(2',4')
# Scraping details for: 5th Generation district heating and cooling in the Efteling
# Scraping details for: 5x buurtbeheer
# Scraping details for: 60GHz FMCW radar system with high distance and Doppler resolution and accuracy
# Scraping details for: 60 GHz radio module design and implementation of subsystems
# Scraping details for: 60 GHz wireless power transfer - system analysis and Doherty power amplifier design: 4-stage Doherty power amplifier
# Scraping page 4...
# Scraping details for: 6LoWPAN: IPv6 for battery-less building networks
# Scraping details for: 7-8-9: serie die zich contextueel gedraagt
# Scraping details for: 8044 SDLC/HDLC controller
# Scraping details for: 80 kW isolated DC/DC converter for railway applications
# Scraping details for: A_green_house: literatuurstudie : transparant overkapte ruimtes
# Scraping details for: A_topia: living in the clouds
# Scraping details for: A_void block21: ontwerp voor groot stedelijk bouwblok aan de Zuidas, Amsterdam
# Scraping details for: A.P.L. : achtergronden en taalbeschrijving
# Scraping details for: A (max, +) based trade-off exploration between storage and throughput for scenario-aware dataflow
# Scraping details for: A 10-bit folding and interpolating A/D-converter for low-power video applications
# Scraping details for: A 1 MHz wide bandgap power amplifier for high-precision applications
# Scraping details for: A 20 GHz stage differential class B power amplifier with on-chip balun in SiGe QUBIC4X BiCMOS
# Scraping details for: A 21st century Capsule Tower for inner city density
# Scraping details for: A 270 GHz broadband frequency multiplier in 40-nm CMOS
# Scraping details for: A 29Si CP-MAS NMR study of deactivation techniques in capillary gas chromatography
# Scraping details for: A 2-D finite element model of a muscle cell in agarose gel-matrix
# Scraping details for: A 2-dimensional magnetic levitation-system
# Scraping details for: A 2-echelon capacitated location-routing problem for early applications of food distribution network designs
# Scraping details for: A2-kantoortoren te Maastricht : stadspoort van Maastricht
# Scraping details for: A2RID: An Anonymous RemoteID-compliant Group Signature Scheme for Commercial Drones
# Scraping details for: A 3D co-culture model of mesenchymal stem cells and endothelial cells to promote vascularization and osteogenesis in bone tissue engineering
# Scraping details for: A 3-D finite element model of the tibialis anterior muscle of a rat: a contribution to pressure sores research
# Scraping details for: A 3D modeller for implicit surface skeletons
# Scraping details for: A 3-D structural skin model: development and implementation
# Scraping details for: A4 Midden-Delfland : meervoudig ruimtegebruik op het grensvlak van stad, land en infrastructuur
# Scraping details for: A 5bit 1GS/s 2.7mW time-interleaved asynchronous digital slope ADC
# Scraping details for: A 6.65 m Normal Incidence Spectrometer (NIS) for high resolution spectroscopy in the VUV
# Scraping details for: A 60GHz, 12.5 GHz 1dB bandwidth fully integrated power amplifier using a distributed ring transformer in CMOS 65nm
# Scraping details for: A 60 GHz fully integrated power amplifier using a distributed transformer in CMOS 45 nm
# Scraping details for: A 8044 look-a-like SDLC/HDLC controller
# Scraping details for: AAL security and privacy: Transferring XACML policies for end to end access and usage control
# Scraping details for: Aanbevelingen voor de klimatisering van een museum voor scheepsarcheologie
# Scraping details for: Aanbevelingen voor methoden voor het ontwikkelen van telematicasystemen
# Scraping details for: Aanbevelingen voor voorraadbeheersing met betrekking tot "lumpy demand" bij Sikkens
# Scraping details for: Aanbodcreatie proces van recreatief winkelen
# Scraping details for: Aanbouwsysteem voor woningverbetering
# Scraping details for: Aanbrengen van krimpkappen om verschillende typen beeldbuizen met behulp van een universele automaat
# Scraping details for: Aandachtspunten
# Scraping details for: 'Aandacht voor de omgeving': een onderzoek naar de invloed van een combinatie van fysieke en sociale eigenschappen van een omgeving op het restoratieve effect van die omgeving
# Scraping details for: Aandacht voor kwaliteit bij de aanschaf van brandweermaterieel
# Scraping details for: Aandacht voor leverbetrouwbaarheid: noodzaak voor kwaliteit en continuïteit
# Scraping details for: A and B allowables for the 3-p Weibull distribution
# Scraping details for: Aandrijvingen van een 3D-meetmachine
# Scraping details for: Aangepaste produktiesystemen voor de ontwikkelingslanden
# Scraping details for: Aangiftebereidheid van computercriminaliteit bij bedrijven
# Scraping details for: Aan het einde van de Leien: aanvulling op het historisch stadscentrum van Antwerpen
# Scraping details for: Aan hoger wal : villa te Nijmegen . Randverschijnselen : projekt te Den Bosch
# Scraping details for: Aankoopbeleid van fleetowners
# Scraping details for: Aankopen en verbeteren in de gemeente Utrecht : financieel-economische evaluatie van zes jaar praktijk met het stadsvernieuwings-instrument aankopen en verbeteren
# Scraping details for: Aanloopkosten in productprojecten : onderzoek naar reductie- en beheersingsmogelijkheden
# Scraping page 5...
# Scraping details for: Aanloopverschijnselen van de synchrone motor
# Scraping details for: Aan normen waarde(n) hechten: het gebruik van normen en prestatie-beoordeling bij de produktiebesturing van het Grafisch Bedrijf
# Scraping details for: Aanpak scheefwoners: strategieanalyse voor de omgang met scheefwoners in het Stedelijk Gebied Eindhoven
# Scraping details for: Aanpak verbeteringsprojecten en ontwikkeling management van verbeteringen bij de EED
# Scraping details for: Aanpasbaarheid van bestaande draagconstructies in het kader van duurzaam bouwen
# Scraping details for: Aanpasbaarheid van de draagconstructie: onderzoek naar de haalbaarheid en ontwerp van verplaatsbare kolommen in een draagconstructie
# Scraping details for: Aanpasbaarheid van woningen: een onderzoek naar indicatoren voor aanpasbaarheid van woningen in het kader van duurzaamheid
# Scraping details for: Aanpasbaarheid van woningen . Analyse Tivoli
# Scraping details for: Aanpasbaar wonen . Wonen naar maat
# Scraping details for: Aanpasbaar woonmilieu : van theorie naar praktijk(?)
# Scraping details for: Aanpassen aan de groei: het ontwerp van een jaarproductieplanning
# Scraping details for: Aanpassingen aan bloedsuikermeetapparatuur t.b.v. visueel gehandicapte diabetici
# Scraping details for: Aanpassingen aan de 124Xe-bestralingsopstelling voor routinematige produktie van 123I op de THE
# Scraping details for: Aanpassingen aan een model en inleidende metingen aan een testopstelling voor een hoogvermogen pulsbuis
# Scraping details for: Aanpassing en ontwerp van een injecteermachine
# Scraping details for: Aanpassingen van een proefopstelling van een optisch abonnee systeem
# Scraping details for: Aanpassing van een automatische meetopstelling voor ultrasone tomografie aan de IEEE-488 bus
# Scraping details for: Aanpassing van het software pakket "VISION" aan de frame grabber DT2861 van Data Translation
# Scraping details for: Aanschaf van reservedelen: een vergelijk van vijf modellen binnen de Defensie Materieel Organisatie toegepast op single en multi-echelon praktijksituaties
# Scraping details for: Aansluiting school-bedrijf : ontwikkeling en toetsing van een methode van onderzoek
# Scraping details for: Aansluitingsproblemen bij wiskunde: de overgang van het vwo naar de technische universiteit
# Scraping details for: Aansluitingsproblemen met wiskunde bij eerstejaarsstudenten van de TUE
# Scraping details for: Aansprakelijkheid en logistiek: een onderzoek in Ziekenhuis Rijnstate naar de logistiek van steriele disposables mede in relatie tot de nieuwe aansprakelijkheidswetgeving
# Scraping details for: Aanstroomproblemen van grote gefluidiseerde bedden
# Scraping details for: Aansturing van distributieknooppunten met electronic data interchange
# Scraping details for: Aansturing van lineaire akoestische array's voor ultrasone transmissie tomografie
# Scraping details for: Aansturing van motoronderhoudsprojecten bij Maintenance Unit CF6
# Scraping details for: Aantrekkelijke produktgroepen voor Roll-fed labeling en het verkoop analyse model
# Scraping details for: Aanvang van het onderzoek naar de optimale afscheiding van olienevels in een kontinu proces aan draad- en vezel-pakketten en poreuse polymeren bij een minimale drukval
# Scraping details for: Aanvoerstromen geanalyseerd: een vergeten kostenpost?
# Scraping details for: Aanvoer van bloemen en planten: de wachtrijproblematiek
# Scraping details for: Aan wat vooraf ging: een analoge interventie bij een bestaand gebouw
# Scraping details for: Aanzet marktwaardebepaling zorgvastgoed: een onderzoek naar het bepalen van de marktwaarde van het verpleeghuis binnen de verpleging en verzorgingssector
# Scraping details for: Aanzetten tot uitzetten: een onderzoek naar de mogelijkheden om het huishoudelijk stand-by verbruik terug te dringen
# Scraping details for: Aanzet tot businessplan Philips Transport en Expeditie B.V.
# Scraping details for: Aanzet tot de implementatie van een Ethernet verbinding tussen de Intel 310 en de THE KUNix machine
# Scraping details for: Aanzet tot de ontwikkeling van een betere procesbeheersing
# Scraping details for: Aanzet tot de ontwikkeling van een informatiesysteem voor het werken met Markov-modellen
# Scraping details for: Aanzet tot de produktie en de detectie van metastabiel helium bij temperaturen van 0,05 tot 4,2 K
# Scraping details for: Aanzet tot de structurering van de marketing informatie voor Philips' telecommunicatie industrie
# Scraping details for: Aanzet tot een analyse- en waarderingsmethode voor oude stadsgebieden
# Scraping details for: Aanzet tot een decision support system voor stedelijke vernieuwingsprojecten : Utrecht City Project als referentie project
# Scraping details for: Aanzet tot een digitale real-time simulator voor transienten in netten
# Scraping details for: Aanzet tot een geintegreerde MOST audioversterker
# Scraping details for: Aanzet tot een handleiding voor instellingsplanning ten behoeve van instellingen voor algemeen maatschappelijk werk
# Scraping details for: Aanzet tot een M.I.S. en uitwerking van het informatiesysteem onderwijs
# Scraping details for: Aanzet tot een nieuwe bereidingswijze van DNA-achtige molekulen
# Scraping details for: Aanzet tot een nieuw LCA-model voor gebouwen: theoretische en praktische knelpunten in de levenscyclusanalyse voor gebouwen en de zwaartepunten in het milieuprofiel van woningen
# Scraping details for: Aanzet tot een ontwerp van een kostenanalysesysteem ten behoeve van de logistiek
# Scraping details for: Aanzet tot een praktijk richtlijn kwaliteitsborging van de voedingsverzorging in instellingen
# Scraping page 6...
# Scraping details for: Aanzet tot een systeem voor de generatie van snijpatronen in een plaatwerkbedrijf
# Scraping details for: Aanzet tot een taal waarmee bouwkundige artefacten kunnen worden beschreven
# Scraping details for: Aanzet tot het karakteriseren van het relaxatiegedrag van HP-PE vezels met behulp van het 1 dimensionaal schapery relaxatie model : tussenrapport
# Scraping details for: Aanzet tot het ontwerpen van een bloedvatdiameter-meter
# Scraping details for: Aanzet tot het ontwerp van een informatiesysteem voor het werken met Markov-modellen
# Scraping details for: Aanzet tot het ontwerp van een logistieke structuur voor de afdeling Distributie van de NV PNEM
# Scraping details for: Aanzet tot het ontwerp van een probleemklassifikatie
# Scraping details for: Aanzet tot het ontwerp van een produktiebesturingssysteem
# Scraping details for: Aanzet tot kwaliteitsverbetering bij Multisol Raambekleding BV
# Scraping details for: Aanzet tot kwaliteitsverbetering van veelpolige miniatuurmagneten
# Scraping details for: Aanzet tot mogelijke instrumentatie van de diameterbepaling van een bloedvat m.b.v. frequentie-gemoduleerd ultrageluid
# Scraping details for: Aanzet tot simultane meting van magnetische susceptibiliteit en elektrische geleidbaarheid met SQUID-gradiometer-opstelling
# Scraping details for: Aanzet tot toekomstige layout
# Scraping details for: Aanzet voor een softwarepakket ter analyse van de afwijkingenstructuur van meerassige machines
# Scraping details for: Aardbevingen en de Dubai Tower : een literatuurstudie naar aardbevingen en een dynamische responsieberekening van de Dubai Tower uitgevoerd met het computerprogramma M.V.S.
# Scraping details for: Aardtunnel-ventilatie : koelen en (voor)verwarmen van ventilatielucht door uitwisseling en opslag van warmte in de bodem
# Scraping details for: A basis for the order-to-order method: theory and validation
# Scraping details for: Abattoirs d'Anderlecht: restoring the symbolic value of a propelling monument
# Scraping details for: ABCB1 variants in association with clopidogrel response
# Scraping details for: ABC cycle counting: een raamwerk om voorraadgegevens nauwkeurig te krijgen én te houden
# Scraping details for: A BDD based prover for mCRL2
# Scraping details for: Abdominal aortic aneurysms : a numerical/experimental approach
# Scraping details for: A behavioral model for rationing : decision rules with situational bounds to incentivize forecasting performance in an integrated planning environment: a case study: designing the allocation planning process for Hilti's internal end-to-end supply chain
# Scraping details for: A benchmark set for process discovery algorithms
# Scraping details for: A better interface for automated program transformation
# Scraping details for: A better world for Orphans: Creating a healthy living environment for orphans where a future can be worked on
# Scraping details for: A Bijlmer experience: de Bijlmerroute als verbindend ruimtelijk en programmatisch element in de Bijlmer
# Scraping details for: A billboardshelter in Dar es Salaam
# Scraping details for: A BIM-integrated approach to construction quality management: enabling information and knowledge management during the execution phase of a project life cycle
# Scraping details for: Ab-initio insights into the tunability of the electronic structure in transition metal dichalcogenide alloys grown by atomic layer deposition
# Scraping details for: A biomechanical view on atrial fibrillation: feasibility of stretch-activated ectopic beats in the left atrium
# Scraping details for: A blockchain-based supply chain contract: an analysis to the development of a supply chain contract on a blockchain
# Scraping details for: A Blueprint for Reverse Logistics in the High-Tech OEM Industry: Design of a Reference Architecture using an Enterprise Modeling Approach
# Scraping details for: A body-contact-free respiration sensor in magnetic resonance imaging
# Scraping details for: A bottum-up approach for modeling the performance of partially shaded PV systems with power optimizers
# Scraping details for: A boundary element method for microscopic Stokes flow in deep drawing processes
# Scraping details for: About the synthesis and analysis of encapsulated salt hydrates as PCM-slurry
# Scraping details for: Above the chaos
# Scraping details for: A brain chip to investigate neurite outgrowth by trapping cell-laden hydrogel beads in microsieves
# Scraping details for: A brain-computer interface for walking using EEG
# Scraping details for: A branching process on a hypercubic lattice
# Scraping details for: Abrasive wear of ethylene-octene copolymers and blends of these materials with high density polyethylene in relation to various physical properties
# Scraping details for: A breathtaking journey
# Scraping details for: A breeding ground for innovation: peer-to-peer assistance in the hybrid model of innovation
# Scraping details for: A brickyard deconstruction: the redevelopment of brickyard 'Elden' & the Meinerswijk landscape
# Scraping details for: A brief encounter with Vincent: the effect on self-compassion from a single interaction with a chatbot that gives or asks for help
# Scraping details for: A brief exploration into divergent series in probability theory
# Scraping details for: A Brief Introduction to Traffic Modelling with a Closer Look at the Nagel-Schreckenberg Model
# Scraping details for: A broadband and high-sensitivity frontend design for UHF RFID tag
# Scraping details for: A broadly applicable red dye doped Luminescent Solar Concentrator photo microreactor
# Scraping page 7...
# Scraping details for: Absolute Atomic Hydrogen Densities in Low Pressure Electron Cyclotron Resonance Plasmas measured using Optical Emission Spectroscopy
# Scraping details for: Absolute botsingsdoorsneden voor argon en krypton
# Scraping details for: Absolute Stress Measurement at the Microscale Using High Resolution Electron Backscatter Diffraction and Focused Ion Beam Ring-core Milling
# Scraping details for: Absorptiecoefficienten van inhomogene magnetoplasma's
# Scraping details for: Absorptie en fluorescentie effecten bij röntgen-spectrometrie
# Scraping details for: Absorptie en reflektiemetingen aan GaSe
# Scraping details for: Absorptiekoeling met behulp van restwarmte bij een drukkerij
# Scraping details for: Absorptie van ethylene in zwavelzure mengsels: een oppervlakte reaktie
# Scraping details for: Absorptie van publiekvlak in schaalmodel nagalmkamer : ontwikkelen van een meetmethode
# Scraping details for: Absorption loss analysis and color tuning of plasmonic phosphor based LEDs
# Scraping details for: Absorption spectra on some metal halide molecules used in HID lamps
# Scraping details for: Absorption spectroscopy of nitric oxide in a volume dielectric barrier discharge
# Scraping details for: Absorption spectroscopy on microwave induced Ar - SiCl4 plasmas
# Scraping details for: Absorption spectroscopy on O2 production in an atmospheric pressure dielectric barrier discharge in CO2
# Scraping details for: Abstracting real-valued parameters in parameterised boolean equation systems
# Scraping details for: Abstract interpretation of concurrent logic programs for analysis of variable sharing
# Scraping details for: Abstraction raising in MLIR
# Scraping details for: Abstraktie van kategorieinformatie
# Scraping details for: Abtstraat Maastricht : een voorstel tot herbebouwing met studentenhuisvesting en gezinswoningen
# Scraping details for: A business case for connecting coffee machines to IoT
# Scraping details for: A business process harmonization approach: using process mining techniques
# Scraping details for: AC/DC power modulation for corona plasma generation
# Scraping details for: AC/DC pulsed power corona
# Scraping details for: Academic technology-driven entrepreneurship: "the design of an entrepreneurship education program at the Eindhoven University of Technology"
# Scraping details for: A calculus for combinational circuits consisting of switches
# Scraping details for: A campus in transition: adapting the Maastricht Health Campus for a future with autonomous transport
# Scraping details for: A cap, fine & reward policy framework: creating energy consciousness and urging residents to save energy?
# Scraping details for: A carbon-coated QCM-based atomic hydrogen sensor for in-situ plasma diagnostics
# Scraping details for: A cardiac finite element model of the left ventricular mechanics: from canine towards human model
# Scraping details for: A case study into increasing warranty costs in the Lighting Electronics industry
# Scraping details for: A case study of reporting business KPIs of gaming data through static and interactive visualizations
# Scraping details for: A Case Study on Performance Degradation of Cooling Coils in the Netherlands
# Scraping details for: A case study on the possibilities and constraints of GIS for urban planning and management in Dar es Salaam
# Scraping details for: A cause-effect diagram to support the management of the financial impact of a supply chain disruption: Disruption Analyses of the Supply Chain due to Corona Virus, based on actual information, with focus on Manufacturing Industry
# Scraping details for: Accelerated deconvolution for radio-astronomical imaging using artificial intelligence
# Scraping details for: Accelerated lifetime determination of IGBT modules
# Scraping details for: Accelerated target capture at a sensor surface by microfluidic stirring with magnetic particles
# Scraping details for: Accelerated Wafer Z-map for layout independent leveling
# Scraping details for: Accelerating a movie recommender system using VirtualCL on a heterogeneous GPU  cluster: big data analysis using distributed accelerators
# Scraping details for: Accelerating and intensifying the development of sustainable building in the Netherlands: analysis of impedients and opportunities through literature and expert interviews
# Scraping details for: Accelerating early strength and stiffness development of a Portland cement-based mortar for 3D printing
# Scraping details for: Accelerating I/O efficient graph algorithms on grid graphs using the GPU
# Scraping details for: Accelerating MRI with a Quiet Wireless Insert Gradient Coil
# Scraping details for: Accelerating Multiphase Computational Fluid Dynamics using Artificial Neural Networks
# Scraping details for: Accelerating SIFT feature extraction with a vector DSP: a feasibility study
# Scraping details for: Accelerating simulations of electromagnetic waves in hot, magnetized fusion plasmas
# Scraping details for: Accelerating the binding of microparticle-labeled biomarker proteins to a reactive surface for magnetic particle-based sensors
# Scraping details for: Accelerating the energy transition through intermediary management of high-growth energy firms
# Scraping details for: Accelerating the learning curve at ASML: the effect of increased opportunities to learn
# Scraping details for: Accelerating the learning curve at ASML: an exploration of drivers
# Scraped 400 theses in total.

# %% [markdown]
# # Downloading pdfs

# %%
import requests
import json
import os
import re
import sys
from pathlib import Path

# Constants
INPUT_JSON_FILE = 'thesis_titles_links_and_pdfs_and_supervisors.json'
OUTPUT_JSON_FILE = 'thesis_titles_links_and_pdfs_and_supervisors_updated.json'
PDFS_DIR = 'pdfs'

# Reserved Windows filenames
RESERVED_FILENAMES = {
    "CON", "PRN", "AUX", "NUL",
    "COM1", "COM2", "COM3", "COM4", "COM5", "COM6", "COM7", "COM8", "COM9",
    "LPT1", "LPT2", "LPT3", "LPT4", "LPT5", "LPT6", "LPT7", "LPT8", "LPT9"
}

def sanitize_filename(filename):
    """
    Sanitize the filename by removing or replacing invalid characters.
    This function replaces any character not in the whitelist with an underscore.
    Whitelisted characters are alphanumerics, space, hyphen, underscore, parentheses, and period.
    Additionally, it ensures the filename does not end with a space or dot and is not a reserved name.
    """
    # Define a whitelist of valid characters
    whitelist = r'[^A-Za-z0-9 \-_().]'
    # Replace invalid characters with underscore
    sanitized = re.sub(whitelist, '_', filename)
    # Replace multiple underscores with a single one
    sanitized = re.sub(r'_+', '_', sanitized)
    # Strip leading/trailing underscores and whitespace
    sanitized = sanitized.strip(' _')
    # Ensure filename does not end with a space or dot
    sanitized = sanitized.rstrip(' .')
    # Check for reserved filenames (case-insensitive)
    if sanitized.upper() in RESERVED_FILENAMES:
        sanitized = f"_{sanitized}_"
    # Limit the filename length to 255 characters (common filesystem limit)
    return sanitized[:255]

def make_unique_filename(directory, filename):
    """
    Ensure the filename is unique within the specified directory.
    If the filename already exists, append a counter to make it unique.
    """
    base, extension = os.path.splitext(filename)
    counter = 1
    unique_filename = filename
    while os.path.exists(os.path.join(directory, unique_filename)):
        unique_filename = f"{base}_{counter}{extension}"
        counter += 1
    return unique_filename

def download_pdf(thesis, pdf_url, file_path):
    """
    Downloads a PDF from the given URL and saves it to the specified file path.
    Returns True if download is successful, False otherwise.
    """
    try:
        response = requests.get(pdf_url, timeout=30)
        if response.status_code == 200:
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f"Download success for '{thesis['Title']}'")
            return True
        else:
            print(f"Download failed for '{thesis['Title']}' - Status Code: {response.status_code}")
            return False
    except requests.exceptions.RequestException as e:
        print(f"Download failed for '{thesis['Title']}' - Error: {e}")
        return False
    except OSError as e:
        print(f"File write failed for '{thesis['Title']}' - Error: {e}")
        return False

def main():
    # Load thesis data with PDF links
    try:
        with open(INPUT_JSON_FILE, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Input JSON file '{INPUT_JSON_FILE}' not found.")
        sys.exit(1)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        sys.exit(1)

    # Ensure the 'pdfs' directory exists
    Path(PDFS_DIR).mkdir(parents=True, exist_ok=True)

    # Process each thesis entry
    for thesis in data:
        pdf_url = thesis.get('PDF')
        if pdf_url and isinstance(pdf_url, str) and pdf_url.strip().lower() != 'no pdf found':
            original_title = thesis.get('Title', 'untitled')
            sanitized_title = sanitize_filename(original_title)
            filename = f"{sanitized_title}.pdf"
            # Ensure the filename is unique within the directory
            unique_filename = make_unique_filename(PDFS_DIR, filename)
            file_path = os.path.join(PDFS_DIR, unique_filename)
            relative_path = f"./{PDFS_DIR}/{unique_filename}"

            # Download the PDF
            success = download_pdf(thesis, pdf_url, file_path)

            # Update JSON data based on the download outcome
            if success:
                thesis['file'] = relative_path
            else:
                thesis['file'] = "Download failed"
        else:
            thesis['file'] = "No PDF found"

    # Save the updated JSON data to a new file
    try:
        with open(OUTPUT_JSON_FILE, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        print(f"Updated JSON data saved to '{OUTPUT_JSON_FILE}'.")
    except IOError as e:
        print(f"Error writing to JSON file: {e}")

if __name__ == "__main__":
    main()
# Out:
# Download success for '/JoiCost/ : berekeningen aan stalen raamwerken'
# Download success for '"...but some are more equal than others": development of an instrument for software performance prioritization'
# Download success for '.NL'
# Download success for '(Ab)using Bitcoin for anti-censorship tool'
# Download success for '(C)PO in de gemeentelijke organisatie: het Kavelpaspoort als kritische succesfactor'
# Download success for '(De)centrale inkoop èn synergie? bij NBM-Amstelland, Infrastructuur en Milieu: een verslag van een afstudeeronderzoek naar de mogelijkheden tot het realiseren van synergie middels coördinatie binnen een gedecentraliseerde inkooporganisatie'
# Download success for '(Discrete) strategies for the binary multiplying channel'
# Download success for '(Door)breekbaar'
# Download success for '(ei)Land : een zoektocht naar stedenbouw en architectuur : van masterplan tot woningplattegrond'
# Download success for '(Her)gebruikt bouwen: demontage en hergebruik van geprefabriceerde betonelementen van naoorlogse (montage-)systeembouwwoningen'
# Download success for '(Her-)ontwerp van bedrijfsprocessen: de invloed van veranderprogramma's op bedrijfsprocessen'
# Download success for '(I)ADL assistive robot for older adults with dementia'
# Download success for '(In,Ga)N heterostructures in self-assembled GaN nanowires grown on TiN by molecular beam epitaxy'
# Download success for '(In)security of video surveillance systems in building automation systems'
# Download success for '(In)visible illusion: architecture for co-existence'
# Download success for '(On)gebonden frame: woon/werk omgeving voor de creatieve klasse van Eindhoven binnen een vrij en duurzaam kader'
# Download success for '(On-)gekoppelde voorraadbeheersing bij ASML te Veldhoven'
# Download success for '(Re)defining Neways Advanced Applications' life cycle services offering'
# Download success for '(re)form block: urban block housing'
# Download success for '(S)cars: a treatment for Boston's big dig'
# Download success for '(Sociale woningbouw)2 : ontwerpfase : het ontwerpen van een milieubewuste en betaalbare seniorenwoning'
# Download success for '(Sustainable) reconstruction of World Heritage property'
# Download success for '(Ultra-) Small angle X-ray scattering on asphaltenes : mathematical modelling and physical conclusions'
# File write failed for '(Verplichte) samenwerking tussen projectontwikkelaar en aannnemer bij het ontwikkelingsproces: een beslissingsondersteunend model voor de projectontwikkelaar om in de (pré)initiatieffase te toetsen of de 'eigen' aannemer geschikt is om het project te realiseren' - Error: [Errno 22] Invalid argument: 'pdfs\\(Verplichte) samenwerking tussen projectontwikkelaar en aannnemer bij het ontwikkelingsproces_ een beslissingsondersteunend model voor de projectontwikkelaar om in de (pr_)initiatieffase te toetsen of de _eigen_ aannemer geschikt is om het project te real.pdf'
# Download success for '(Voor-)ontwerp van een transportsysteem voor productstroken'
# Download success for '[Green H2Ousing]: landstedelijk en autarkisch wonen in de IJsselzone te Zwolle'
# Download success for '-[S]antoniem: transformatie van tijdelijk naar definitief'
# Download success for '[Under Dock]: herbestemming van een droogdok tot een nieuwe stedelijke ruimte met pop- en jongerencentrum in de Lisnave scheepswerf in Almada, Portugal'
# Download success for 'µ-Plasma assisted deposition of titanium dioxide thin films'
# Download success for 'µPlasmaPrinting of amine-containing polymer films using APTMS(3-aminopropyl trimethoxysilane)'
# Download success for '1/f noise as a diagnostic tool, and 1/f noise in the extinction coefficient of optical fibres'
# Download success for '1/f noise in ferromagnetic tunnel junctions'
# Download success for '1/f-ruis in de thermospanning van intrinsiek germanium'
# Download success for '1/f ruis in geleiders en in het Hall-effekt'
# Download success for '1/f ruis in laserdiodes'
# Download success for '1/f ruis in laserlicht'
# Download success for '1/f-ruis in magnetoweerstanden met verschillende lengte/breedte verhoudingen'
# Download success for '1/f ruis in MOS-transistoren'
# Download success for '1/f ruis in MOS-transistoren'
# Download success for '1/f-ruis in P+-N fotodiodes'
# Download success for '1/f ruismetingen met behulp van de vierpuntsprobe'
# Download success for '1/f ruis van bipolaire transistoren'
# Download success for '1 + 1 = één?: afstudeerrapport: integratie bij DeliXL Schiedam en DeliXL Barendrecht'
# Download success for '"1+1>2?!": Synergiemogelijkheden in de fysieke distributie van DSM op de lokatie Geleen'
# Download success for '123I-produktie via de (P,2N)- en (P,PN)-reactie op 124XE'
# Download success for '12 Bit, 250 MSamples/s current steering DAC'
# Download success for '13/13 machinefabriek: herbestemming van de machinefabriek te Vlissingen'
# Download success for '1 B.O.M. en verder?: prototyping van een stuklijst- en bewerkingensysteem'
# Download success for '1D parameter study on tar conversion in counterflow diffusion flames'
# Download success for '1MORE: architectural design of a new mobile telephony service'
# Download success for '2001 : A water oddity : het toepassen van een gemetselde boogconstructie op het ontwerp van een zwembadcomplex'
# Download success for '2020: Duurzame energie in de woningbouw: en de rol van Nuon Tecno'
# Download success for '21 Century intergenerational cohousing community: Interplay of overlapping spaces in an intergenerational cohousing building in Eindhoven to limit the building footprint and improve quality of life in city centres'
# Download success for '2-channel mono playback in cinema and room in room acoustics: the effect of direct field interference on playback quality of diffuse-field recordings'
# Download success for '2-class Terror Queue model: Analysis and optimal assignment of agents'
# Download success for '2D and 3D capacitance calculations for MOS VLSI'
# Download success for '2D Core flow instability in a wide vaneless diffuser: experimental set-up design'
# Download success for '2D Detection of Carton Boxes from RGB images'
# Download success for '2D Electron thermal transport and electron thermal transport near magnetic islands'
# Download success for '2-D flow evolution in bounded domains'
# Download success for '2D in-cylinder temperature and fuel distribution measurements using two-color LIF'
# Download success for '2D magneto-optical trap as source for cold ions'
# Download success for '2D numerical model of droplet breakup in emulsions: development of a numerical model to predict the number and size after breakup of droplets in simple shear flow'
# Download success for '2D perovskite solar cells based on powder and crystal precursors'
# Download success for '2D-proeven op lijmwerk: rapportage laboratoriumonderzoek'
# Download success for '2-D temperatuurmetingen met behulp van "laser-induced fluorescence"'
# Download success for '2FACE centrum voor raamprostitutie: een aanpasbaar winkelcentrum'
# Download success for '3D adaptable building skin: mechanisme onderzoek corpus vivera architectura'
# Download success for '3D cache-oblivious multi-scale traversals of meshes using 8-reptile polyhedra'
# Download success for '3D concrete printing: research and development of a structural reinforcement system for 3D printing with concrete'
# Download success for '3D concrete printing: The applicability of different characterization methods to determine the mechanical material properties of 3D printable pastes with various aggregates and fibers'
# Download success for '3D concrete printing in architecture: a research on the potential benefits of 3D concrete printing in the construction of residential buildings in the Netherlands'
# Download success for '3D Face Reconstruction Using Deep Learning'
# Download success for '3D face reconstruction using structured light on a hand-held device'
# Download success for '3D fingerprint detection in ancient museum sculptures from CT data'
# Download success for '3Dflexmould: development of a self-supporting double curved glass dome'
# Download success for '3D geometry reconstruction based on limited experimental data'
# Download success for '3D geometry reconstruction of multi-phase materials with limited experimental data using the Phase Field method'
# Download success for '3D graphics rendering for multiview displays'
# Download success for '3D-graphics rendering on a multiprocessor architecture'
# Download success for '3D map creating using the structured light technique for obstacle avoidance'
# Download success for '3D Modelling and validation of boiler emissions using the Flamelet Generated Manifold technique'
# Download success for '3D Object Detection From LiDAR data using Distance Depended Feature Extraction'
# Download success for '3D point cloud reconstruction from photographs using a spring embedder algorithm'
# Download success for '3D-printed electrodes for redox flow batteries'
# Download success for '3D printed façade panel'
# Download success for '3D printing as an emerging general purpose technology: opportunities & challenges'
# Download success for '3D printing of concrete structures'
# Download success for '3D printing of microfluidic chips with different modules for point-of-care testing applications'
# Download success for '3D Printing of Polymer-Derived Ceramics'
# Download success for '3D PTV applied to a viscous flow in a cylindrical domain'
# Download success for '3D reconstruction and analysis of branching streamer discharges: elementary processes in gas discharges'
# Download success for '3D reconstruction of streamer discharges using mathematical algorithms: based on predictive back-end reconstruction, minimum spanning trees and sub-Riemannian geometry'
# Download success for '3D scalar field simulations for Micro Mixing applications in a cylindrical geometry: implementation and verification'
# Download success for '3D segmentatie en visualisatie in MR angiografie'
# Download success for '3D skin body reconstruction'
# Download success for '3D template matching on the GPU'
# Download success for '3D thermische modellering van een laagspanningspatroon voor de beveiliging van halfgeleidercomponenten in EMTP'
# Download success for '3D-TV signal conversion algorithms and embedded architectures'
# Download success for '3D viewing experience: the induction and measurement of discomfort for stereoscopic content with motion on 3DTVs'
# Download success for '3D workpiece reconstruction from 2D images : using top-view cameras'
# Download success for '3G introduction in China'
# Download success for '3He/4He-mengkoeler met tweevoudige mengkamer'
# Download success for '3MO-TION: 3DCP movement and circulation'
# Download success for '3 woningen, 3 landen, 1 landschap'
# Download success for '4C-ing customer constraints : analysing the effects of customer requirements on logistics costs and performance for Philips Consumer Electronics' DC Acht'
# Download success for '4-kanaals meetversterker'
# Download success for '4 Prijsvragen (en Helmut Jahn)'
# Download success for '4-vector correlatiemetingen aan Ne(2P)5(3P)-He botsingen in de Mini-Bundel I opstelling'
# Download success for '55+ housing in 2040: insights in the future supply and demand of attractive and appropriate 55+ housing'
# Download success for '5-daagse ruwbouwcyclus voor hoogbouwprojecten: een hulpmiddel voor het begeleiden van het calculatieteam bij het ontwerpen van een 5-daagse ruwbouwcyclus voor een hoogbouwproject'
# Download success for '5G Business models: Considerations for organizations'
# Download success for '5th Generation district heating and cooling in the Efteling'
# Download success for '60 GHz radio module design and implementation of subsystems'
# Download success for '60 GHz wireless power transfer - system analysis and Doherty power amplifier design: 4-stage Doherty power amplifier'
# Download success for '6LoWPAN: IPv6 for battery-less building networks'
# Download success for '7-8-9: serie die zich contextueel gedraagt'
# Download success for '8044 SDLC/HDLC controller'
# Download success for 'A_green_house: literatuurstudie : transparant overkapte ruimtes'
# Download success for 'A_topia: living in the clouds'
# Download success for 'A.P.L. : achtergronden en taalbeschrijving'
# Download success for 'A (max, +) based trade-off exploration between storage and throughput for scenario-aware dataflow'
# Download success for 'A 21st century Capsule Tower for inner city density'
# Download success for 'A 2-dimensional magnetic levitation-system'
# Download success for 'A 2-echelon capacitated location-routing problem for early applications of food distribution network designs'
# Download success for 'A2-kantoortoren te Maastricht : stadspoort van Maastricht'
# Download success for 'A2RID: An Anonymous RemoteID-compliant Group Signature Scheme for Commercial Drones'
# Download success for 'A 6.65 m Normal Incidence Spectrometer (NIS) for high resolution spectroscopy in the VUV'
# Download success for 'A 8044 look-a-like SDLC/HDLC controller'
# Download success for 'AAL security and privacy: Transferring XACML policies for end to end access and usage control'
# Download success for 'Aanbevelingen voor methoden voor het ontwikkelen van telematicasystemen'
# Download success for 'Aanbevelingen voor voorraadbeheersing met betrekking tot "lumpy demand" bij Sikkens'
# Download success for 'Aanbodcreatie proces van recreatief winkelen'
# Download success for 'Aanbrengen van krimpkappen om verschillende typen beeldbuizen met behulp van een universele automaat'
# Download success for ''Aandacht voor de omgeving': een onderzoek naar de invloed van een combinatie van fysieke en sociale eigenschappen van een omgeving op het restoratieve effect van die omgeving'
# Download success for 'Aandacht voor kwaliteit bij de aanschaf van brandweermaterieel'
# Download success for 'Aandacht voor leverbetrouwbaarheid: noodzaak voor kwaliteit en continuïteit'
# Download success for 'Aangiftebereidheid van computercriminaliteit bij bedrijven'
# Download success for 'Aan het einde van de Leien: aanvulling op het historisch stadscentrum van Antwerpen'
# Download success for 'Aanloopkosten in productprojecten : onderzoek naar reductie- en beheersingsmogelijkheden'
# Download success for 'Aanloopverschijnselen van de synchrone motor'
# Download failed for 'Aan normen waarde(n) hechten: het gebruik van normen en prestatie-beoordeling bij de produktiebesturing van het Grafisch Bedrijf' - Error: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# Download success for 'Aanpak scheefwoners: strategieanalyse voor de omgang met scheefwoners in het Stedelijk Gebied Eindhoven'
# Download success for 'Aanpak verbeteringsprojecten en ontwikkeling management van verbeteringen bij de EED'
# Download success for 'Aanpasbaarheid van bestaande draagconstructies in het kader van duurzaam bouwen'
# Download success for 'Aanpasbaarheid van de draagconstructie: onderzoek naar de haalbaarheid en ontwerp van verplaatsbare kolommen in een draagconstructie'
# Download success for 'Aanpasbaarheid van woningen: een onderzoek naar indicatoren voor aanpasbaarheid van woningen in het kader van duurzaamheid'
# Download success for 'Aanpassen aan de groei: het ontwerp van een jaarproductieplanning'
# Download success for 'Aanpassingen aan bloedsuikermeetapparatuur t.b.v. visueel gehandicapte diabetici'
# Download success for 'Aanpassingen aan de 124Xe-bestralingsopstelling voor routinematige produktie van 123I op de THE'
# Download success for 'Aanpassingen aan een model en inleidende metingen aan een testopstelling voor een hoogvermogen pulsbuis'
# Download success for 'Aanpassingen van een proefopstelling van een optisch abonnee systeem'
# Download success for 'Aanpassing van een automatische meetopstelling voor ultrasone tomografie aan de IEEE-488 bus'
# Download success for 'Aanpassing van het software pakket "VISION" aan de frame grabber DT2861 van Data Translation'
# Download success for 'Aanschaf van reservedelen: een vergelijk van vijf modellen binnen de Defensie Materieel Organisatie toegepast op single en multi-echelon praktijksituaties'
# Download success for 'Aansluitingsproblemen bij wiskunde: de overgang van het vwo naar de technische universiteit'
# Download success for 'Aansluitingsproblemen met wiskunde bij eerstejaarsstudenten van de TUE'
# Download success for 'Aansprakelijkheid en logistiek: een onderzoek in Ziekenhuis Rijnstate naar de logistiek van steriele disposables mede in relatie tot de nieuwe aansprakelijkheidswetgeving'
# Download success for 'Aanstroomproblemen van grote gefluidiseerde bedden'
# Download success for 'Aansturing van distributieknooppunten met electronic data interchange'
# Download success for 'Aansturing van lineaire akoestische array's voor ultrasone transmissie tomografie'
# Download success for 'Aansturing van motoronderhoudsprojecten bij Maintenance Unit CF6'
# Download success for 'Aantrekkelijke produktgroepen voor Roll-fed labeling en het verkoop analyse model'
# Download success for 'Aanvang van het onderzoek naar de optimale afscheiding van olienevels in een kontinu proces aan draad- en vezel-pakketten en poreuse polymeren bij een minimale drukval'
# Download success for 'Aanvoerstromen geanalyseerd: een vergeten kostenpost?'
# Download success for 'Aanvoer van bloemen en planten: de wachtrijproblematiek'
# Download success for 'Aan wat vooraf ging: een analoge interventie bij een bestaand gebouw'
# Download success for 'Aanzet marktwaardebepaling zorgvastgoed: een onderzoek naar het bepalen van de marktwaarde van het verpleeghuis binnen de verpleging en verzorgingssector'
# Download success for 'Aanzetten tot uitzetten: een onderzoek naar de mogelijkheden om het huishoudelijk stand-by verbruik terug te dringen'
# Download success for 'Aanzet tot de implementatie van een Ethernet verbinding tussen de Intel 310 en de THE KUNix machine'
# Download success for 'Aanzet tot de produktie en de detectie van metastabiel helium bij temperaturen van 0,05 tot 4,2 K'
# Download success for 'Aanzet tot een digitale real-time simulator voor transienten in netten'
# Download success for 'Aanzet tot een geintegreerde MOST audioversterker'
# Download success for 'Aanzet tot het ontwerpen van een bloedvatdiameter-meter'
# Download success for 'Aanzet tot kwaliteitsverbetering bij Multisol Raambekleding BV'
# Download success for 'Aanzet tot kwaliteitsverbetering van veelpolige miniatuurmagneten'
# Download success for 'Aanzet tot mogelijke instrumentatie van de diameterbepaling van een bloedvat m.b.v. frequentie-gemoduleerd ultrageluid'
# Download success for 'Aanzet tot simultane meting van magnetische susceptibiliteit en elektrische geleidbaarheid met SQUID-gradiometer-opstelling'
# Download success for 'Aardbevingen en de Dubai Tower : een literatuurstudie naar aardbevingen en een dynamische responsieberekening van de Dubai Tower uitgevoerd met het computerprogramma M.V.S.'
# Download success for 'A basis for the order-to-order method: theory and validation'
# Download success for 'Abattoirs d'Anderlecht: restoring the symbolic value of a propelling monument'
# Download success for 'ABC cycle counting: een raamwerk om voorraadgegevens nauwkeurig te krijgen én te houden'
# Download success for 'A BDD based prover for mCRL2'
# File write failed for 'A behavioral model for rationing : decision rules with situational bounds to incentivize forecasting performance in an integrated planning environment: a case study: designing the allocation planning process for Hilti's internal end-to-end supply chain' - Error: [Errno 22] Invalid argument: 'pdfs\\A behavioral model for rationing _ decision rules with situational bounds to incentivize forecasting performance in an integrated planning environment_ a case study_ designing the allocation planning process for Hilti_s internal end-to-end supply chain.pdf'
# Download success for 'A benchmark set for process discovery algorithms'
# Download success for 'A better interface for automated program transformation'
# Download success for 'A better world for Orphans: Creating a healthy living environment for orphans where a future can be worked on'
# Download success for 'A Bijlmer experience: de Bijlmerroute als verbindend ruimtelijk en programmatisch element in de Bijlmer'
# Download success for 'A BIM-integrated approach to construction quality management: enabling information and knowledge management during the execution phase of a project life cycle'
# Download success for 'Ab-initio insights into the tunability of the electronic structure in transition metal dichalcogenide alloys grown by atomic layer deposition'
# Download success for 'A blockchain-based supply chain contract: an analysis to the development of a supply chain contract on a blockchain'
# Download success for 'A Blueprint for Reverse Logistics in the High-Tech OEM Industry: Design of a Reference Architecture using an Enterprise Modeling Approach'
# Download success for 'A body-contact-free respiration sensor in magnetic resonance imaging'
# Download success for 'A bottum-up approach for modeling the performance of partially shaded PV systems with power optimizers'
# Download success for 'A boundary element method for microscopic Stokes flow in deep drawing processes'
# Download success for 'Above the chaos'
# Download success for 'A brain-computer interface for walking using EEG'
# Download success for 'A branching process on a hypercubic lattice'
# Download success for 'A breeding ground for innovation: peer-to-peer assistance in the hybrid model of innovation'
# Download success for 'A brickyard deconstruction: the redevelopment of brickyard 'Elden' & the Meinerswijk landscape'
# Download success for 'A brief encounter with Vincent: the effect on self-compassion from a single interaction with a chatbot that gives or asks for help'
# Download success for 'A brief exploration into divergent series in probability theory'
# Download success for 'A Brief Introduction to Traffic Modelling with a Closer Look at the Nagel-Schreckenberg Model'
# Download success for 'A broadly applicable red dye doped Luminescent Solar Concentrator photo microreactor'
# Download success for 'Absolute Atomic Hydrogen Densities in Low Pressure Electron Cyclotron Resonance Plasmas measured using Optical Emission Spectroscopy'
# Download success for 'Absolute botsingsdoorsneden voor argon en krypton'
# Download success for 'Absorptiecoefficienten van inhomogene magnetoplasma's'
# Download success for 'Absorptie en fluorescentie effecten bij röntgen-spectrometrie'
# Download success for 'Absorptie en reflektiemetingen aan GaSe'
# Download success for 'Absorptie van ethylene in zwavelzure mengsels: een oppervlakte reaktie'
# Download success for 'Absorption spectra on some metal halide molecules used in HID lamps'
# Download success for 'Absorption spectroscopy of nitric oxide in a volume dielectric barrier discharge'
# Download success for 'Absorption spectroscopy on microwave induced Ar - SiCl4 plasmas'
# Download success for 'Absorption spectroscopy on O2 production in an atmospheric pressure dielectric barrier discharge in CO2'
# Download success for 'Abstracting real-valued parameters in parameterised boolean equation systems'
# Download success for 'Abstraction raising in MLIR'
# Download success for 'Abstraktie van kategorieinformatie'
# Download success for 'A business case for connecting coffee machines to IoT'
# Download success for 'A business process harmonization approach: using process mining techniques'
# Download success for 'AC/DC power modulation for corona plasma generation'
# Download success for 'AC/DC pulsed power corona'
# Download success for 'Academic technology-driven entrepreneurship: "the design of an entrepreneurship education program at the Eindhoven University of Technology"'
# Download success for 'A campus in transition: adapting the Maastricht Health Campus for a future with autonomous transport'
# Download success for 'A cap, fine & reward policy framework: creating energy consciousness and urging residents to save energy?'
# Download success for 'A carbon-coated QCM-based atomic hydrogen sensor for in-situ plasma diagnostics'
# Download success for 'A case study into increasing warranty costs in the Lighting Electronics industry'
# Download success for 'A case study of reporting business KPIs of gaming data through static and interactive visualizations'
# Download success for 'A Case Study on Performance Degradation of Cooling Coils in the Netherlands'
# Download success for 'A case study on the possibilities and constraints of GIS for urban planning and management in Dar es Salaam'
# Download success for 'A cause-effect diagram to support the management of the financial impact of a supply chain disruption: Disruption Analyses of the Supply Chain due to Corona Virus, based on actual information, with focus on Manufacturing Industry'
# Download success for 'Accelerated deconvolution for radio-astronomical imaging using artificial intelligence'
# Download success for 'Accelerated target capture at a sensor surface by microfluidic stirring with magnetic particles'
# Download success for 'Accelerated Wafer Z-map for layout independent leveling'
# Download success for 'Accelerating a movie recommender system using VirtualCL on a heterogeneous GPU  cluster: big data analysis using distributed accelerators'
# Download success for 'Accelerating and intensifying the development of sustainable building in the Netherlands: analysis of impedients and opportunities through literature and expert interviews'
# Download success for 'Accelerating early strength and stiffness development of a Portland cement-based mortar for 3D printing'
# Download success for 'Accelerating I/O efficient graph algorithms on grid graphs using the GPU'
# Download success for 'Accelerating MRI with a Quiet Wireless Insert Gradient Coil'
# Download success for 'Accelerating Multiphase Computational Fluid Dynamics using Artificial Neural Networks'
# Download success for 'Accelerating SIFT feature extraction with a vector DSP: a feasibility study'
# Download success for 'Accelerating simulations of electromagnetic waves in hot, magnetized fusion plasmas'
# Download success for 'Accelerating the binding of microparticle-labeled biomarker proteins to a reactive surface for magnetic particle-based sensors'
# Download success for 'Accelerating the energy transition through intermediary management of high-growth energy firms'
# Download success for 'Accelerating the learning curve at ASML: the effect of increased opportunities to learn'
# Download success for 'Accelerating the learning curve at ASML: an exploration of drivers'
# Updated JSON data saved to 'thesis_titles_links_and_pdfs_and_supervisors_updated.json'.

# %%
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    text = ''
    pdf_document = fitz.open(pdf_path)
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    return text

# Extract text from all PDFs
texts = {}
for thesis in data:
    pdf_path = os.path.join('pdfs', thesis['Title'].replace('/', '_').replace(':', '_') + '.pdf')
    if os.path.exists(pdf_path):
        texts[thesis['Title']] = extract_text_from_pdf(pdf_path)

# %% [markdown]
# # Visualise

# %%
import json
import networkx as nx
from pyvis.network import Network

# Load the thesis data
with open('thesis_titles_links_and_pdfs_and_supervisors.json', 'r', encoding='utf-8') as f:
    thesis_data = json.load(f)

from collections import Counter

# Dictionary to hold the count of theses per supervisor
supervisor_counts = Counter()

# List to hold the filtered theses data
filtered_thesis_data = []

for thesis in thesis_data:
    thesis_title = thesis['Title']
    supervisors = thesis.get('Supervisors', [])
    
    # Only consider the first supervisor if available
    if supervisors:
        first_supervisor = supervisors[0]
        supervisor_counts[first_supervisor] += 1
        # Update the thesis data to include only the first supervisor
        thesis['Supervisors'] = [first_supervisor]
        filtered_thesis_data.append(thesis)
    else:
        # Optionally, you can exclude theses without supervisors
        pass  # Skip theses without supervisors

# Get the top 20 supervisors
top_supervisors = [supervisor for supervisor, count in supervisor_counts.most_common(20)]

# Filter theses supervised by the top 20 supervisors
top_thesis_data = [thesis for thesis in filtered_thesis_data if thesis['Supervisors'][0] in top_supervisors]

# Create a NetworkX graph
G = nx.Graph()

# Add nodes and edges to the graph
for thesis in top_thesis_data:
    thesis_title = thesis['Title']
    supervisor = thesis['Supervisors'][0]
    
    # Add the thesis node with a 'type' attribute
    G.add_node(thesis_title, type='thesis', title=thesis_title)
    
    # Add supervisor node if it doesn't exist
    if not G.has_node(supervisor):
        G.add_node(supervisor, type='supervisor', title=supervisor)
    
    # Add an edge between the thesis and the supervisor
    G.add_edge(thesis_title, supervisor)

# Create a PyVis network
net = Network(notebook=False, height='750px', width='100%', bgcolor='#ffffff', font_color='black')

# Customize the physics of the network for better layout
net.barnes_hut(gravity=-2000, central_gravity=0.3, spring_length=95, spring_strength=0.01, damping=0.09)

# Add nodes and edges from the NetworkX graph to the PyVis network
for node, data in G.nodes(data=True):
    node_type = data.get('type', 'thesis')
    if node_type == 'thesis':
        net.add_node(node, label=node, title=node, color='lightblue', shape='dot', size=5)
    else:
        net.add_node(node, label=node, title=node, color='orange', shape='dot', size=15)

for source, target in G.edges():
    net.add_edge(source, target)

# Generate the network visualization and save it as an HTML file
net.show('top_supervisors_network.html')

# %%
import json

# Replace 'data.json' with the path to your JSON file
with open('thesis_titles_links_and_pdfs_and_supervisors_updated.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# Open the markdown file for writing
with open('readme.md', 'w', encoding='utf-8') as md_file:
    for item in data:
        title = item.get('Title', 'No Title')
        url = item.get('URL', 'No URL')
        pdf = item.get('PDF', 'No PDF')
        supervisors = item.get('Supervisors', [])

        md_file.write(f"# {title}\n\n")
        md_file.write(f"- **URL**: [{url}]({url})\n")
        md_file.write(f"- **PDF**: [{pdf}]({pdf})\n")
        if supervisors:
            supervisors_list = ', '.join(supervisors)
            md_file.write(f"- **Supervisors**: {supervisors_list}\n\n")
        else:
            md_file.write(f"- **Supervisors**: None\n\n")
